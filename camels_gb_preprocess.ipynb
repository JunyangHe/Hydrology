# %%
import numpy as np
import pandas as pd
import os
from pathlib import Path, PosixPath
from tqdm import tqdm
import sys
import glob
import datetime
from typing import List
import json

# %%
CREATE_CSV_FILES = True
CAMELS_COMBINED = True
root_path = "/content/gdrive/MyDrive/Colab Datasets/Hydrology/gb"

from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Create csv Files

# %% [markdown]
# ## Read Timeseries Files

# %%
# read dynamic
def to_datetime(s):
  date = s.split('-')
  year = int(date[0])
  month = int(date[1])
  day = int(date[2])
  d = datetime.date(year, month, day)
  return d


def read_timeseries_data(data_dir: str):
  files = list(Path(data_dir).glob('CAMELS_GB_hydromet_timeseries_*.csv'))
  input = []

  for csv in files:
    file_name = os.path.basename(csv)
    names = file_name.split('_')

    df_input = pd.read_csv(csv, dtype=None)
    df_input['basin_id'] = int(names[4])
    df_input['date'].apply(to_datetime)
    input.append(df_input)

  timeseries_data = pd.concat(input, axis=0, copy=False)

  return timeseries_data

# %%
if CREATE_CSV_FILES:
  timeseries_dir = root_path + "/data/timeseries"
  timeseries_data = read_timeseries_data(timeseries_dir)
  forcing_data = timeseries_data[['date', 'basin_id', 'precipitation', 'temperature']]
  discharge_data = timeseries_data[['date', 'basin_id', 'discharge_spec']]

  forcing_data.to_csv(root_path + "/forcing_data_gb.csv", index=False)
  discharge_data.to_csv(root_path + "/discharge_data_gb.csv", index=False)

# %% [markdown]
# ## Read Attributes Files

# %%
def read_attributes(data_dir: str):
    files = list(Path(data_dir).glob('CAMELS_GB_*_attributes.csv'))

    data_list = []

    pbar = tqdm(files, file=sys.stdout, position=0)
    for fpath in pbar:
        pbar.set_description("process " + fpath.name)
        data = pd.read_csv(fpath)
        data['gauge_id'].astype('int64')

        data_list.append(data)

    attributes = pd.concat(data_list, axis=1, copy=False)

    return attributes

# %%
if CREATE_CSV_FILES:
  attributes_dir = root_path + "/data"
  attr = read_attributes(attributes_dir)
  attr.to_csv(root_path + "/attributes_gb.csv", index=False)
  attr = attr.astype({"gauge_id": int}, errors='raise')
  attr
# Out:
# process CAMELS_GB_topographic_attributes.csv: 100%|██████████| 8/8 [00:04<00:00,  1.87it/s]

# %% [markdown]
# # Read csv Files

# %%
BASIN_COL = 'basin_id'
DATE_COL = 'date'

# %%
# read csvs
attr_p = pd.read_csv(root_path + "/attributes_gb.csv")
discharge_p = pd.read_csv(root_path + "/discharge_data_gb.csv")
forcing_p = pd.read_csv(root_path + "/forcing_data_gb.csv")

# %%
forcing_p.dtypes
# Out:
# date              object
# basin_id           int64
# precipitation    float64
# temperature      float64
# dtype: object

# %%
locs = np.union1d(np.union1d(forcing_p[BASIN_COL], discharge_p[BASIN_COL]), attr_p['gauge_id'])
Nloc = len(locs)

print('Initial Nloc', Nloc)
# Out:
# Initial Nloc 671

# %% [markdown]
# ## Sanity Check

# %%
def remove_basins_globally(basins: List[int]):
  global discharge_p
  global forcing_p
  global attr_p
  global locs
  global Nloc

  print("removing", basins)

  discharge_p.drop(discharge_p[discharge_p[BASIN_COL].isin(basins)].index, inplace=True, errors='ignore')
  forcing_p.drop(forcing_p[forcing_p[BASIN_COL].isin(basins)].index, inplace=True, errors='ignore')
  attr_p.drop(attr_p[attr_p['gauge_id'].isin(basins)].index, inplace=True, errors='ignore')

  locs = np.setdiff1d(locs, basins)
  Nloc = len(locs)
  print('new Nloc', Nloc)

# %%
intersect = np.intersect1d(np.intersect1d(forcing_p[BASIN_COL], discharge_p[BASIN_COL]), attr_p['gauge_id'])

diff = np.setdiff1d(locs, intersect)
print("diff", diff)

if len(diff) > 0:
  remove_basins_globally(diff)
# Out:
# diff []

# %%
def find_time_range(df: pd.DataFrame):
  groups = df[[BASIN_COL, DATE_COL]].groupby([BASIN_COL])
  counts = groups.count()

  abnormal_cols = counts[counts[DATE_COL] < 1000].index.values

  if len(abnormal_cols) > 0:
    print('abnormal cols', abnormal_cols)
    remove_basins_globally(abnormal_cols)
    groups = df[[BASIN_COL, DATE_COL]].groupby([BASIN_COL])

  mins = groups.min()
  maxs = groups.max()

  min_d  = np.max(mins.values)
  max_d  = np.min(maxs.values)
  print("range", min_d, max_d)

  return min_d, max_d

# %%
min1, max1 = find_time_range(discharge_p)
min2, max2 = find_time_range(forcing_p)
# Out:
# range 1970-10-01 2015-09-30
# range 1970-10-01 2015-09-30

# %%
InitialDate = max(min1, min2)
InitialDate = "1989-10-02"
print("InitialDate ", InitialDate)


EndDate = min(max1, max2)
EndDate = "2008-12-31"
print("EndDate ", EndDate)
# Out:
# InitialDate  1989-10-02
# EndDate  2008-12-31

# %%
# filter data sets based on the InitialDate and EndDate
discharge_p.drop(discharge_p[(discharge_p[DATE_COL] < InitialDate) | (discharge_p[DATE_COL] > EndDate)].index,
                 inplace=True, errors='ignore')
forcing_p.drop(forcing_p[(forcing_p[DATE_COL] < InitialDate) | (forcing_p[DATE_COL] > EndDate)].index,
                 inplace=True, errors='ignore')

# %% [markdown]
# ## Dynamic Data

# %%
input_p = forcing_p.merge(discharge_p, on=[BASIN_COL, DATE_COL], copy=True, validate="1:1")
input_p
# Out:
#                date  basin_id  precipitation  temperature  discharge_spec
# 0        1989-10-02     10002           0.00         8.71            0.27
# 1        1989-10-03     10002           0.00         9.63            0.27
# 2        1989-10-04     10002           0.39        11.12            0.27
# 3        1989-10-05     10002           5.69        11.32            0.30
# 4        1989-10-06     10002           2.52         9.24            0.31
# ...             ...       ...            ...          ...             ...
# 4717796  2008-12-27     96004           0.04        -1.20            1.08
# 4717797  2008-12-28     96004           0.00        -2.45            0.91
# 4717798  2008-12-29     96004           0.00        -2.75            0.82
# 4717799  2008-12-30     96004           0.02        -6.09            0.56
# 4717800  2008-12-31     96004           0.08        -3.65            0.77
#
# [4717801 rows x 5 columns]

# %%
input_p.rename(columns = {'date':'Year_Mnth_Day', 'basin_id':'basin_id', 'precipitation':'prcp(mm/day)', 'temperature':'tmean(C)', 'discharge_spec':'QObs(mm/d)'}, inplace = True)

# %%
input_p.sort_values(["Year_Mnth_Day", BASIN_COL], inplace=True, ignore_index=True)

# %%
input_p.sort_values(["Year_Mnth_Day", BASIN_COL], inplace=True, ignore_index=True)
input_p['QObs(mm/d)'] = input_p['QObs(mm/d)'].fillna(input_p['QObs(mm/d)'].mean())
input_p['prcp(mm/day)'] = input_p['prcp(mm/day)'].astype('float')
input_p = input_p[~(input_p['Year_Mnth_Day'] < '1989-10-02')]
input_p = input_p[~(input_p['Year_Mnth_Day'] > '2008-12-31')]
input_p['Year_Mnth_Day'] = pd.to_datetime(input_p['Year_Mnth_Day'], format='%Y-%m-%d')

# %%
assert len(input_p) == len (forcing_p) and len(input_p) == len (discharge_p)

# %%
BasicInputTimeSeries = input_p.to_numpy()

# %%
print(BasicInputTimeSeries.shape)
print(BasicInputTimeSeries[0])
# Out:
# (4717801, 5)
# [Timestamp('1989-10-02 00:00:00') 1001 0.02 8.5 1.9407891071608745]

# %% [markdown]
# ## Static Data

# %%
INVALID_ATTR= []

if CAMELS_COMBINED:
  INVALID_ATTR = [
      'gauge_name', 'gauge_id', 'gauge_easting', 'gauge_northing', 'gauge_elevation', 'dpsbar', 'elev_min', 'elev_10',
      'elev_50', 'elev_90', 'elev_max', 'baseflow_index_ceh', 'dwood_perc', 'ewood_perc', 'grass_perc', 'shrub_perc', 'crop_perc',
      'urban_perc', 'inwater_perc', 'bares_perc', 'gauge_elev'
  ]

# else:
#   # Test fitting GB data into US model
#   INVALID_ATTR = [
#       'gauge_name', 'gauge_id', 'gauge_elev', 'area', 'gauge_easting', 'gauge_northing', 'gauge_elevation', 'dpsbar', 'elev_min', 'elev_10',
#       'elev_50', 'elev_90', 'elev_max', 'baseflow_index_ceh'
#   ]

# %%
gauge_id = attr_p['gauge_id'].tolist()

# %%
filtered_attr = attr_p.copy()
filtered_attr.drop(INVALID_ATTR, axis=1, inplace=True, errors='ignore')
filtered_attr.insert(0, 'gauge_id', gauge_id)
filtered_attr.dtypes
# Out:
# gauge_id             int64
# inter_high_perc    float64
# inter_mod_perc     float64
# inter_low_perc     float64
# frac_high_perc     float64
#                     ...
# gauge_id.7           int64
# gauge_lat          float64
# gauge_lon          float64
# area               float64
# elev_mean          float64
# Length: 134, dtype: object

# %%
# Re-order Columns
filtered_attr = filtered_attr[['gauge_id', 'p_mean', 'pet_mean', 'p_seasonality', 'frac_snow', 'aridity', 'high_prec_freq',
                               'high_prec_dur', 'high_prec_timing', 'low_prec_freq', 'low_prec_dur', 'low_prec_timing', 'q_mean',
                               'runoff_ratio', 'slope_fdc', 'baseflow_index', 'stream_elas', 'Q5', 'Q95', 'high_q_freq',
                               'high_q_dur', 'low_q_freq', 'low_q_dur', 'zero_q_freq', 'hfd_mean', 'gauge_lat', 'gauge_lon',
                               'elev_mean', 'area', 'dom_land_cover']]

# %%
assert len(filtered_attr) == Nloc

# %%
# Categorical variable encoding
cols = filtered_attr.columns
categorical_cols = filtered_attr.select_dtypes(exclude = ['number']).columns

for cat_col in categorical_cols:
  num_cat = filtered_attr[cat_col].value_counts().count()
  filtered_attr[cat_col] = (filtered_attr[cat_col].astype('category').cat.codes)/num_cat

  print('Processed ', cat_col)
# Out:
# Processed  high_prec_timing
# Processed  low_prec_timing
# Processed  dom_land_cover
# <ipython-input-29-9d2cd170c9d6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_attr[cat_col] = (filtered_attr[cat_col].astype('category').cat.codes)/num_cat
# <ipython-input-29-9d2cd170c9d6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_attr[cat_col] = (filtered_attr[cat_col].astype('category').cat.codes)/num_cat
# <ipython-input-29-9d2cd170c9d6>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_attr[cat_col] = (filtered_attr[cat_col].astype('category').cat.codes)/num_cat

# %%
filtered_attr.isna().sum()
# Out:
# gauge_id            0
# p_mean              0
# pet_mean            0
# p_seasonality       0
# frac_snow           0
# aridity             0
# high_prec_freq      0
# high_prec_dur       0
# high_prec_timing    0
# low_prec_freq       0
# low_prec_dur        0
# low_prec_timing     0
# q_mean              0
# runoff_ratio        0
# slope_fdc           3
# baseflow_index      0
# stream_elas         0
# Q5                  0
# Q95                 0
# high_q_freq         0
# high_q_dur          0
# low_q_freq          0
# low_q_dur           0
# zero_q_freq         0
# hfd_mean            0
# gauge_lat           0
# gauge_lon           0
# elev_mean           2
# area                0
# dom_land_cover      0
# dtype: int64

# %%
# Remove NaN values
nan_cols = [col for col in filtered_attr.columns if filtered_attr.isna().sum()[col] > 0]
print(nan_cols)

for nan_col in nan_cols:
  filtered_attr[nan_col] = filtered_attr[nan_col].fillna(filtered_attr[nan_col].mean())
# Out:
# ['slope_fdc', 'elev_mean']
# <ipython-input-31-bd6338c072e3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_attr[nan_col] = filtered_attr[nan_col].fillna(filtered_attr[nan_col].mean())

# %%
BasicInputStaticProps = filtered_attr.to_numpy()
NpropperTimeStatic = len(filtered_attr.columns) - 1
print('NpropperTimeStatic', NpropperTimeStatic)
print(filtered_attr.columns)
# Out:
# NpropperTimeStatic 29
# Index(['gauge_id', 'p_mean', 'pet_mean', 'p_seasonality', 'frac_snow',
#        'aridity', 'high_prec_freq', 'high_prec_dur', 'high_prec_timing',
#        'low_prec_freq', 'low_prec_dur', 'low_prec_timing', 'q_mean',
#        'runoff_ratio', 'slope_fdc', 'baseflow_index', 'stream_elas', 'Q5',
#        'Q95', 'high_q_freq', 'high_q_dur', 'low_q_freq', 'low_q_dur',
#        'zero_q_freq', 'hfd_mean', 'gauge_lat', 'gauge_lon', 'elev_mean',
#        'area', 'dom_land_cover'],
#       dtype='object')

# %% [markdown]
# # Save Datasets

# %%
if CAMELS_COMBINED:
  input_p.to_csv(root_path + "/BasicInputTimeSeries_gb_combined.csv")
  filtered_attr.to_csv(root_path + "/BasicInputStaticProps_gb_combined.csv")
  np.save(root_path + "/BasicInputTimeSeries_gb_combined", BasicInputTimeSeries)
  np.save(root_path + "/BasicInputStaticProps_gb_combined", BasicInputStaticProps)

else:
  input_p.to_csv(root_path + "/BasicInputTimeSeries_gb.csv")
  filtered_attr.to_csv(root_path + "/BasicInputStaticProps_gb.csv")
  np.save(root_path + "/BasicInputTimeSeries_gb", BasicInputTimeSeries)
  np.save(root_path + "/BasicInputStaticProps_gb", BasicInputStaticProps)

# %%
from datetime import datetime
EndDate = datetime.strptime(EndDate, '%Y-%m-%d')
EndDate = np.datetime64(EndDate)
InitialDate = datetime.strptime(InitialDate, '%Y-%m-%d')
InitialDate = np.datetime64(InitialDate)

print(type(EndDate))
int(((EndDate-InitialDate + np.timedelta64(1, 'D'))/np.timedelta64(1, 'D')))
# Out:
# <class 'numpy.datetime64'>
# 7031

# %%
meta_data = {
    'Nloc': Nloc,
    'locs': locs.tolist(),
    'loc_names': attr_p['gauge_name'].tolist(),
    'BasicInputTimeSeries':{
      'fields': input_p.columns.values.tolist(),
      'index_fields': [BASIN_COL, DATE_COL],
      'initial_date': str(InitialDate),
      'end_date': str(EndDate),
      'time_delta': str(BasicInputTimeSeries[1, 1] - BasicInputTimeSeries[0, 1]),
      'time_steps': int(((EndDate-InitialDate + np.timedelta64(1, 'D'))/np.timedelta64(1, 'D'))),
    },
    'BasicInputStaticProps': {
        'fields': filtered_attr.columns.values.tolist(),
        'index_fileds': ['gauge_id'],
    },
    'NpropperTimeStatic': len(filtered_attr.columns) - 1
}

# %%
if CAMELS_COMBINED:
  with open(root_path + "/metadata_gb_combined.json", 'w') as outfile:
    json.dump(meta_data, outfile, indent='\t')

else:
  with open(root_path + "/metadata_gb.json", 'w') as outfile:
    json.dump(meta_data, outfile, indent='\t')

# %%
BasicInputTimeSeries
# Out:
# array([[Timestamp('1989-10-02 00:00:00'), 1001, 0.02, 8.5,
#         1.9407891071608745],
#        [Timestamp('1989-10-02 00:00:00'), 2001, 0.0, 7.6, 0.21],
#        [Timestamp('1989-10-02 00:00:00'), 2002, 0.0, 7.22,
#         1.9407891071608745],
#        ...,
#        [Timestamp('2008-12-31 00:00:00'), 102001, 0.0, -0.91, 1.14],
#        [Timestamp('2008-12-31 00:00:00'), 106001, 0.0, 1.89, 2.33],
#        [Timestamp('2008-12-31 00:00:00'), 107001, 1.07, -1.94, 0.94]],
#       dtype=object)

# %%
type(BasicInputTimeSeries[0,3])
# Out:
# float

# %%
str(InitialDate)
# Out:
# '1989-10-02T00:00:00.000000'

# %%
str(BasicInputTimeSeries[1, 1] - BasicInputTimeSeries[0, 1])
print(BasicInputTimeSeries[1,1])
print(BasicInputTimeSeries[0,1])
# Out:
# 2001
# 1001

# %%
meta_data
# Out:
# {'Nloc': 671,
#  'locs': [1001,
#   2001,
#   2002,
#   3003,
#   4001,
#   4003,
#   4005,
#   4006,
#   5003,
#   6007,
#   6008,
#   7001,
#   7002,
#   7003,
#   7005,
#   7006,
#   8004,
#   8005,
#   8006,
#   8009,
#   8011,
#   8013,
#   9002,
#   9003,
#   9004,
#   9005,
#   10002,
#   10003,
#   11001,
#   11003,
#   11004,
#   12001,
#   12002,
#   12005,
#   12006,
#   12007,
#   12008,
#   12009,
#   13001,
#   13004,
#   13005,
#   13007,
#   13008,
#   14001,
#   14002,
#   14005,
#   15006,
#   15007,
#   15010,
#   15011,
#   15012,
#   15013,
#   15014,
#   15016,
#   15021,
#   15023,
#   15024,
#   15025,
#   15030,
#   15039,
#   16001,
#   16003,
#   16004,
#   17001,
#   17003,
#   17004,
#   17005,
#   17015,
#   17018,
#   18001,
#   18002,
#   18003,
#   18008,
#   18010,
#   18011,
#   18014,
#   18017,
#   18018,
#   19001,
#   19006,
#   19010,
#   19017,
#   19020,
#   20002,
#   20003,
#   20007,
#   21003,
#   21006,
#   21008,
#   21009,
#   21011,
#   21012,
#   21013,
#   21015,
#   21016,
#   21017,
#   21018,
#   21022,
#   21023,
#   21024,
#   21026,
#   21027,
#   22001,
#   22006,
#   22007,
#   22009,
#   23001,
#   23004,
#   23006,
#   23007,
#   23008,
#   23011,
#   23016,
#   24001,
#   24003,
#   24004,
#   24005,
#   25001,
#   25003,
#   25006,
#   25012,
#   25020,
#   25021,
#   25029,
#   26003,
#   26005,
#   26006,
#   26008,
#   26009,
#   27001,
#   27002,
#   27003,
#   27006,
#   27007,
#   27009,
#   27021,
#   27023,
#   27025,
#   27026,
#   27029,
#   27030,
#   27032,
#   27034,
#   27035,
#   27038,
#   27041,
#   27042,
#   27043,
#   27047,
#   27049,
#   27051,
#   27062,
#   27064,
#   27065,
#   27071,
#   27073,
#   27077,
#   27079,
#   27080,
#   27084,
#   27087,
#   27089,
#   27090,
#   28001,
#   28003,
#   28008,
#   28009,
#   28012,
#   28015,
#   28018,
#   28022,
#   28023,
#   28024,
#   28026,
#   28031,
#   28033,
#   28039,
#   28040,
#   28043,
#   28044,
#   28046,
#   28048,
#   28050,
#   28052,
#   28055,
#   28056,
#   28060,
#   28066,
#   28067,
#   28072,
#   28074,
#   28080,
#   28081,
#   28082,
#   28085,
#   28091,
#   28093,
#   28115,
#   28116,
#   28117,
#   29002,
#   29003,
#   29005,
#   29009,
#   30001,
#   30004,
#   30005,
#   30011,
#   30012,
#   30014,
#   30015,
#   31002,
#   31006,
#   31010,
#   31021,
#   31023,
#   31025,
#   32003,
#   32004,
#   32006,
#   32008,
#   33006,
#   33007,
#   33012,
#   33013,
#   33014,
#   33018,
#   33019,
#   33020,
#   33021,
#   33022,
#   33023,
#   33024,
#   33026,
#   33028,
#   33029,
#   33031,
#   33032,
#   33033,
#   33034,
#   33035,
#   33039,
#   33053,
#   33054,
#   33058,
#   34002,
#   34003,
#   34004,
#   34005,
#   34006,
#   34007,
#   34008,
#   34010,
#   34011,
#   34012,
#   35003,
#   35008,
#   36003,
#   36006,
#   36009,
#   36010,
#   36011,
#   36012,
#   37001,
#   37003,
#   37005,
#   37008,
#   37009,
#   37010,
#   37011,
#   37018,
#   37019,
#   37020,
#   37031,
#   37033,
#   38001,
#   38003,
#   38004,
#   38007,
#   38012,
#   38014,
#   38017,
#   38018,
#   38021,
#   38026,
#   38029,
#   38030,
#   39001,
#   39002,
#   39004,
#   39005,
#   39006,
#   39007,
#   39008,
#   39010,
#   39011,
#   39012,
#   39014,
#   39015,
#   39016,
#   39017,
#   39019,
#   39020,
#   39021,
#   39022,
#   39023,
#   39025,
#   39027,
#   39028,
#   39029,
#   39034,
#   39035,
#   39036,
#   39037,
#   39042,
#   39049,
#   39052,
#   39054,
#   39056,
#   39061,
#   39065,
#   39069,
#   39072,
#   39078,
#   39081,
#   39087,
#   39088,
#   39095,
#   39099,
#   39101,
#   39105,
#   39108,
#   39114,
#   39120,
#   39125,
#   39127,
#   39141,
#   39142,
#   39143,
#   39144,
#   40003,
#   40004,
#   40005,
#   40006,
#   40007,
#   40009,
#   40010,
#   40011,
#   40012,
#   40013,
#   40016,
#   40017,
#   40018,
#   40020,
#   40021,
#   40022,
#   40033,
#   41001,
#   41003,
#   41004,
#   41005,
#   41006,
#   41009,
#   41011,
#   41012,
#   41013,
#   41014,
#   41016,
#   41019,
#   41020,
#   41022,
#   41023,
#   41025,
#   41027,
#   41028,
#   41029,
#   42001,
#   42003,
#   42004,
#   42006,
#   42008,
#   42010,
#   42011,
#   42016,
#   42017,
#   42024,
#   42026,
#   42027,
#   43005,
#   43006,
#   43007,
#   43008,
#   43009,
#   43014,
#   43017,
#   43018,
#   43021,
#   44001,
#   44002,
#   44006,
#   44009,
#   44011,
#   45001,
#   45003,
#   45004,
#   45005,
#   45009,
#   45012,
#   46003,
#   46005,
#   46008,
#   46014,
#   47001,
#   47004,
#   47005,
#   47008,
#   47009,
#   47011,
#   47014,
#   47018,
#   48003,
#   48004,
#   48005,
#   48011,
#   49001,
#   49002,
#   49004,
#   50001,
#   50002,
#   50006,
#   50007,
#   50008,
#   50011,
#   51001,
#   52004,
#   52005,
#   52006,
#   52007,
#   52009,
#   52010,
#   52011,
#   52015,
#   52016,
#   53005,
#   53006,
#   53007,
#   53008,
#   53009,
#   53013,
#   53017,
#   53018,
#   53022,
#   53023,
#   53028,
#   54001,
#   54002,
#   54003,
#   54004,
#   54005,
#   54007,
#   54008,
#   54011,
#   54012,
#   54015,
#   54016,
#   54017,
#   54018,
#   54019,
#   54020,
#   54022,
#   54024,
#   54025,
#   54027,
#   54028,
#   54029,
#   54032,
#   54034,
#   54036,
#   54038,
#   54044,
#   54048,
#   54049,
#   54052,
#   54057,
#   54060,
#   54063,
#   54080,
#   54095,
#   54096,
#   55002,
#   55007,
#   55008,
#   55013,
#   55014,
#   55016,
#   55018,
#   55021,
#   55023,
#   55025,
#   55026,
#   55029,
#   55032,
#   56001,
#   56002,
#   56007,
#   56012,
#   56013,
#   57004,
#   57005,
#   57006,
#   57007,
#   57008,
#   57009,
#   58001,
#   58002,
#   58006,
#   58008,
#   58009,
#   58010,
#   58012,
#   59001,
#   60002,
#   60003,
#   60005,
#   60006,
#   60010,
#   60012,
#   61001,
#   61002,
#   62001,
#   63001,
#   63004,
#   64001,
#   64002,
#   64006,
#   65001,
#   65004,
#   65005,
#   65006,
#   65007,
#   65008,
#   66001,
#   66004,
#   66006,
#   66011,
#   67001,
#   67005,
#   67006,
#   67008,
#   67010,
#   67015,
#   67018,
#   67025,
#   67033,
#   68001,
#   68003,
#   68004,
#   68005,
#   68020,
#   69002,
#   69007,
#   69012,
#   69015,
#   69017,
#   69023,
#   69027,
#   69030,
#   69032,
#   69043,
#   70002,
#   71001,
#   71004,
#   71006,
#   71008,
#   71014,
#   72002,
#   72004,
#   72005,
#   72007,
#   72009,
#   72014,
#   72015,
#   73005,
#   73009,
#   73010,
#   73011,
#   73014,
#   73015,
#   74001,
#   74005,
#   74006,
#   74007,
#   75003,
#   75004,
#   75017,
#   76003,
#   76005,
#   76007,
#   76008,
#   76011,
#   76014,
#   77002,
#   77003,
#   77004,
#   78003,
#   78004,
#   78006,
#   79002,
#   79003,
#   79004,
#   79005,
#   79006,
#   80001,
#   80002,
#   80003,
#   80004,
#   80005,
#   80006,
#   81002,
#   81003,
#   81004,
#   81006,
#   81007,
#   82001,
#   82003,
#   83003,
#   83004,
#   83006,
#   83007,
#   83009,
#   83010,
#   83013,
#   84001,
#   84004,
#   84005,
#   84008,
#   84009,
#   84012,
#   84013,
#   84014,
#   84016,
#   84017,
#   84018,
#   84019,
#   84020,
#   84022,
#   84026,
#   84030,
#   85001,
#   85002,
#   85003,
#   85004,
#   88001,
#   89002,
#   89003,
#   89005,
#   89007,
#   90003,
#   92001,
#   93001,
#   94001,
#   95001,
#   96001,
#   96002,
#   96004,
#   97002,
#   101002,
#   101005,
#   102001,
#   106001,
#   107001],
#  'loc_names': ['Ugie at Inverugie',
#   'Ythan at Ellon',
#   'Wick at Tarroul',
#   'Medina at Shide',
#   'Eastern Yar at Budbridge',
#   'Cefni at Bodffordd',
#   'Creed at Creed Bridge',
#   'Durkadale at Durkadale',
#   'Don at Parkhill',
#   'Don at Bridge of Alford',
#   'Urie at Pitcaple',
#   'Dee at Woodend',
#   'Dee at Park',
#   'Muick at Invermuick',
#   'Gairn at Invergairn',
#   'Dee at Mar Lodge',
#   'Feugh at Heugh Head',
#   'Water of Dye at Charr',
#   'Bervie at Inverbervie',
#   'Prosen Water at Prosen Bridge',
#   'Lunan Water at Kirkton Mill',
#   'North Esk at Logie Mill',
#   'South Esk at Brechin',
#   'Eden at Kemback',
#   'Dighty Water at Balmossie Mill',
#   'Motray Water at St Michaels',
#   'Tay at Ballathie',
#   'Tay at Pitnacree',
#   'Isla at Wester Cardean',
#   'Lyon at Comrie Bridge',
#   'Tummel at Pitlochry',
#   'Almond at Almondbank',
#   'Ardle at Kindrogan',
#   'Tay at Kenmore',
#   'Lunan Burn at Mill Bank',
#   'Braan at Hermitage',
#   'Dochart at Killin',
#   'Ericht at Craighall',
#   'Dean Water at Dean Bridge',
#   'Tilt at Marble Lodge',
#   'Earn at Kinkell Bridge',
#   'Ruchill Water at Cultybraggan',
#   'Earn at Forteviot Bridge',
#   'Carron at Headswood',
#   'Bonny Water at Bonnybridge',
#   'Ore at Balfour Mains',
#   'Avon at Polmonthill',
#   'North Queich at Lathro',
#   'Greens Burn at Damleys Cottage',
#   'Allan Water at Kinbuck',
#   'Devon at Glenochil',
#   'Teith at Bridge of Teith',
#   'Leny at Anie',
#   'Forth at Gargunnock',
#   'Forth at Craigforth',
#   'Bannock Burn at Bannockburn',
#   'Monachyle Burn at Balquhidder',
#   'Kirkton Burn at Balquhidder',
#   'Almond at Craigiehall',
#   'Water of Leith at Murrayfield',
#   'Braid Burn at Liberton',
#   'Gogar Burn at Turnhouse',
#   'Almond at Whitburn',
#   'West Peffer Burn at Luffness',
#   'Tyne at Spilmersford',
#   'Gifford Water at Lennoxlove',
#   'Helmsdale at Kilphedir',
#   'Brora at Bruachrobie',
#   'Tweed at Peebles',
#   'Tweed at Boleside',
#   'Teviot at Ormiston Mill',
#   'Tweed at Norham',
#   'Yarrow Water at Philiphaugh',
#   'Teviot at Hawick',
#   'Gala Water at Galashiels',
#   'Leader Water at Earlston',
#   'Eye Water at Eyemouth Mill',
#   'Ettrick Water at Brockhoperig',
#   'Lyne Water at Lyne Station',
#   'Whiteadder Water at Hutton Castle',
#   'Leet Water at Coldstream',
#   'Jed Water at Jedburgh',
#   'Tima Water at Deephope',
#   'Blackadder Water at Mouth Bridge',
#   'Coquet at Morwick',
#   'Blyth at Hartford Bridge',
#   'Wansbeck at Mitford',
#   'Coquet at Rothbury',
#   'Tyne at Bywell',
#   'South Tyne at Haydon Bridge',
#   'South Tyne at Featherstone',
#   'Derwent at Rowlands Gill',
#   'Rede at Rede Bridge',
#   'Kielder Burn at Kielder',
#   'Ouse Burn at Crag Hall',
#   'Wear at Sunderland Bridge',
#   'Wear at Stanhope',
#   'Bedburn Beck at Bedburn',
#   'Browney at Burnhall',
#   'Tees at Darlington Broken Scar',
#   'Trout Beck at Moor House',
#   'Greta at Rutherford Bridge',
#   'Harwood Beck at Harwood',
#   'Skerne at Preston le Skerne',
#   'Skerne at Bradbury',
#   'Leven at Foxton Bridge',
#   'Foston Beck at Foston Mill',
#   'Gypsey Race at Boynton',
#   'Elmswell Beck at Little Driffield',
#   'Mires Beck at North Cave',
#   'West Beck at Snakeholme Lock',
#   'Nidd at Hunsingore Weir',
#   'Wharfe at Wetherby Flint Mill',
#   'Aire at Beal Weir',
#   'Don at Sheffield Hadfields',
#   'Ure at Westwick Lock',
#   'Ouse at Skelton',
#   'Don at Doncaster',
#   'Dearne at Barnsley Weir',
#   'Rother at Woodhouse Mill',
#   'Rother at Whittington',
#   'Calder at Elland',
#   'Dearne at Adwick',
#   'Hebden Beck at Hebden',
#   'Ure at Kilgram Bridge',
#   'Aire at Kildwick Bridge',
#   'Costa Beck at Gatehouses',
#   'Derwent at Buttercrambe',
#   'Dove at Kirkby Mills',
#   'Wharfe at Addingham',
#   'Snaizeholme Beck at Low Houses',
#   'Rye at Ness',
#   'Crimple at Burn Bridge',
#   'Nidd at Skip Bridge',
#   'Went at Walden Stubbs',
#   'Holme at Queens Mill',
#   'Swale at Crakehill',
#   'Brompton Beck at Snainton Ings',
#   'Bradford Beck at Shipley',
#   'Calder at Methley',
#   'Aire at Oulton Lemonroyd',
#   'Eastburn Beck at Crosshills',
#   'Derwent at Low Marishes',
#   'Wharfe at Tadcaster',
#   'Swale at Catterick Bridge',
#   'Derwent at Yorkshire Bridge',
#   'Tame at Water Orton',
#   'Dove at Rocester Weir',
#   'Trent at Colwick',
#   'Trent at Yoxall',
#   'Idle at Mattersey',
#   'Dove at Marston on Dove',
#   'Trent at North Muskham',
#   'Wye at Ashford',
#   'Wreake at Syston Mill',
#   'Anker at Polesworth',
#   'Manifold at Ilam',
#   'Dove at Hollinsclough',
#   'Rea at Calthorpe Park',
#   'Trent at Stoke-On-Trent',
#   'Derwent at Chatsworth',
#   'Poulter at Cuckney',
#   'Dove at Izaak Walton',
#   'Amber at Wingfield Park',
#   'Torne at Auckley',
#   'Sow at Great Bridgeford',
#   'Ecclesbourne at Duffield',
#   'Rothley Brook at Rothley',
#   'Dover Beck at Lowdham',
#   'Cole at Coleshill',
#   'Derwent at Church Wilne',
#   'Greet at Southwell',
#   'Soar at Kegworth',
#   'Tame at Lea Marston Lakes',
#   'Tame at Bescot',
#   'Soar at Littlethorpe',
#   "Derwent at St Mary's Bridge",
#   'Ryton at Blyth',
#   'Soar at Pillings Lock',
#   'Maun at Mansfield the Dykes',
#   'Maun at Whitewater Bridge',
#   'Derwent at Whatstandwell',
#   'Great Eau at Claythorpe Mill',
#   'Lud at Louth',
#   'Rase at Bishopbridge',
#   'Ancholme at Toft Newton',
#   'Witham at Claypole Mill',
#   'Lymn at Partney Mill',
#   'Witham at Saltersford Total',
#   'Bain at Goulceby Bridge',
#   'Stainfield Beck at Cream Poke Farm',
#   'Pointon Lode at Pointon',
#   'Cringle Brook at Stoke Rochford',
#   'Oykel at Easter Turnaig',
#   'Glen at Kates Br & King St Br',
#   'Gwash at Belmesthorpe',
#   'Chater at Fosters Bridge',
#   'Welland at Ashley',
#   'West Glen at Easton Wood',
#   'Gwash South Arm at Manton',
#   'Harpers Brook at Old Mill Bridge',
#   'Ise Brook at Harrowden',
#   'Nene/Kislingbury at Upton Total',
#   'Nene/Kislingbury at Dodford',
#   'Wissey at Northwold Total',
#   'Nar at Marham',
#   'Kym at Meagre Farm',
#   'Sapiston at Rectory Bridge',
#   'Lark at Temple',
#   'Tove at Cappenham Bridge',
#   'Thet at Melford Bridge',
#   'Alconbury Brook at Brampton',
#   'Rhee at Burnt Mill',
#   'Ivel at Blunham',
#   'Lea Brook at Beck Bridge',
#   'Cam at Dernford',
#   'Bedford Ouse at Offord',
#   'Flit at Shefford',
#   'Stringside at Whitebridge',
#   'Broughton Brook at Broughton',
#   'Heacham at Heacham',
#   'Hiz at Arlesey',
#   'Little Ouse at Abbey Heath',
#   'Ely Ouse at Denver Complex',
#   'Bedford Ouse at Roxton',
#   'Granta at Stapleford',
#   'Babingley at Castle Rising',
#   'Ouzel at Bletchley',
#   'Tas at Shotesham',
#   'Bure at Ingworth',
#   'Wensum at Costessey Mill',
#   'Tud at Costessey Park',
#   'Waveney at Needham Mill',
#   'Dove at Oakley Park',
#   'Ant at Honing Lock',
#   'Waveney at Billingford Bridge',
#   'Wensum at Fakenham',
#   'Burn at Burnham Overy',
#   'Alde at Farnham',
#   'Gipping at Stowmarket',
#   'Box at Polstead',
#   'Stour at Langham',
#   'Brett at Cockfield',
#   'Bumpstead Brook at Broad Green',
#   'Stour Brook at Sturmer',
#   'Stour at Kedington',
#   'Roding at Redbridge',
#   'Ter at Crabbs Bridge',
#   'Colne at Lexden',
#   'Chelmer at Springfield',
#   'Brain at Guithavon Valley',
#   'Blackwater at Appleford Bridge',
#   'Chelmer at Churchend',
#   'Ingrebourne at Gaynes Park',
#   'Beam at Bretons Farm',
#   'Chelmer at Felsted',
#   'Crouch at Wickford',
#   'Eastwood Brook at Eastwood',
#   'Lee at Feildes Weir',
#   'Mimram at Panshanger Park',
#   'Rib at Wadesmill',
#   'Canons Brook at Elizabeth Way',
#   'Stevenage Brook at Bragbury Park',
#   'Salmon Brook at Edmonton',
#   'Mimram at Whitwell',
#   'Upper Lee at Water Hall',
#   'Turkey Brook at Albany Park',
#   'Pincey Brook at Sheering Hall',
#   'Quin at Griggs Bridge',
#   'Beane at Hartham',
#   'Thames at Kingston',
#   'Thames at Days Weir',
#   'Wandle at Beddington Park',
#   'Beverley Brook at Wimbledon Common',
#   'Windrush at Newbridge',
#   'Blackwater at Swallowfield',
#   'Thames at Eynsham',
#   'Colne at Denham',
#   'Wey at Tilford',
#   'Hogsmill at Kingston upon Thames',
#   'Ver at Hansteads',
#   'Whitewater at Lodge Farm',
#   'Kennet at Theale',
#   'Ray at Grendon Underwood',
#   'Lambourn at Shaw',
#   'Coln at Bibury',
#   'Cherwell at Enslow Mill',
#   'Loddon at Sheepbridge',
#   'Wye at Hedsor',
#   'Enborne at Brimpton',
#   'Pang at Pangbourne',
#   'Dun at Hungerford',
#   'Tilling Bourne at Shalford',
#   'Evenlode at Cassington Mill',
#   'Churn at Cerney Wick',
#   'Law Brook at Albury',
#   'Kennet at Marlborough',
#   'Leach at Priory Mill Lechlade',
#   'Silk Stream at Colindeep Lane',
#   'The Cut at Binfield',
#   'Mole at Gatwick Airport',
#   'Ravensbourne at Catford Hill',
#   'Letcombe Brook at Letcombe Bassett',
#   'Ewelme Brook at Ewelme',
#   'Mole at Kinnersley Manor',
#   'Thames at Royal Windsor Park',
#   'Wey (North) at Farnham',
#   'Ock at Abingdon',
#   'Ray at Water Eaton',
#   'Chess at Rickmansworth',
#   'Quaggy at Manor House Gardens',
#   'Ampney Brook at Ampney St Peter',
#   'Aldbourne at Ramsbury',
#   'Thame at Wheatley',
#   "Churn at Perrott's Brook",
#   'Pang at Frilsham',
#   'Caker Stream at Alton',
#   'Ver at Redbourn',
#   'Misbourne at Little Missenden',
#   'Wey at Guildford',
#   'Windrush at Bourton on the Water',
#   'Dikler at Bourton on the Water',
#   'Sor at Bodicote',
#   'Medway at Teston / East Farleigh',
#   'Rother at Udiam',
#   'Beult at Stilebridge',
#   'Bourne at Hadlow',
#   'Medway at Chafford / Colliersland Bridge',
#   'Teise at Stonebridge',
#   'Eden at Penshurst / Vexour Bridge',
#   'Great Stour at Horton',
#   'Darent at Hawley',
#   'Darent at Otford',
#   'Cray at Crayford',
#   'Dudwell at Burwash',
#   'Darent at Lullingstone',
#   'Conon at Moy Bridge',
#   'Eridge Stream at Hendal Bridge',
#   'Hexden Channel at Hopemill Bridge Sandhurst',
#   'Great Stour at Chart Leacon',
#   'Dour at Crabble Mill',
#   'Alness at Alness',
#   'Meig at Glenmeanie',
#   'Bran at Dosmucheran',
#   'Nunningham Stream at Tilley Bridge',
#   'Cuckmere at Sherman Bridge',
#   'Ouse at Barcombe Mills',
#   'Ouse at Gold Bridge',
#   'Uck at Isfield',
#   'Rother at Hardham',
#   'Rother at Iping Mill',
#   'Adur E Branch at Sakeham',
#   'Huggletts Stream at Henley Bridge',
#   'Arun at Pallingham',
#   'Cuckmere at Cowbeech',
#   'Arun at Alfoldean',
#   'Bevern Stream at Clappers Bridge',
#   'Lod at Halfway Bridge',
#   'Lavant at Graylingwell',
#   'Loxwood Stream at Drungewick',
#   'Rother at Princes Marsh',
#   'Chess Stream at Chess Bridge',
#   'Bull at Lealands',
#   'Wallington at North Fareham',
#   'Lymington at Brockenhurst',
#   'Test at Broadlands',
#   'Meon at Mislingford',
#   'Cheriton Stream at Sewards Bridge',
#   'Itchen at Highbridge & Allbrook Total',
#   'Hamble at Frogmill',
#   'Itchen at Easton',
#   'Hermitage Stream at Havant',
#   'Test at Chilbolton Total',
#   'Wallop Brook at Bossington',
#   'Dever at Bransbury',
#   'Avon at Amesbury',
#   'Nadder at Wilton',
#   'Stour at Throop',
#   'Wylye at South Newton',
#   'Stour at Hammoon',
#   'East Avon at Upavon',
#   'West Avon at Upavon',
#   'Allen at Walford Mill',
#   'Avon at Knapp Mill',
#   'Frome at East Stoke Total',
#   'Piddle at Baggs Mill',
#   'Sydling Water at Sydling St Nicholas',
#   'Wey at Broadwey',
#   'Asker at East Bridge Bridport',
#   'Exe at Thorverton',
#   'Culm at Woodmill',
#   'Axe at Whitford',
#   'Otter at Dotton',
#   'Exe at Pixton',
#   'Creedy at Cowley',
#   'Dart at Austins Bridge',
#   'East Dart at Bellever',
#   'Avon at Loddiswell',
#   'Teign at Chudleigh',
#   'Tamar at Gunnislake',
#   'Lynher at Pillaton Mill',
#   'Ottery at Werrington Park',
#   'Thrushel at Tinhay',
#   'Tiddy at Tideford',
#   'Plym at Carn Wood',
#   'Walkham at Horrabridge',
#   'Thrushel at Hayne Bridge',
#   'Fal at Tregony',
#   'Warleggan at Trengoffe',
#   'Kenwyn at Truro',
#   'Fowey at Restormel',
#   'Camel at Denby',
#   'Hayle at St Erth',
#   'Gannel at Gwills',
#   'Taw at Umberleigh',
#   'Torridge at Torrington',
#   'Mole at Woodleigh',
#   'Taw at Taw Bridge',
#   'Lew at Gribbleford Bridge',
#   'Okement at Jacobstowe',
#   'Glass at Kerrow Wood',
#   'Doniford Stream at Swill Bridge',
#   'Isle at Ashford Mill',
#   'Tone at Bishops Hull',
#   'Yeo at Pen Mill',
#   'Parrett at Chiselborough',
#   'Sheppey at Fenny Castle',
#   'Brue at Lovington',
#   'Cary at Somerton',
#   'Land Yeo at Wraxall Bridge',
#   'Currypool Stream at Currypool Farm',
#   'Midford Brook at Midford',
#   'Frome (Bristol) at Frenchay',
#   'Frome (Somerset) at Tellisford',
#   'Avon at Great Somerford',
#   'Wellow Brook at Wellow',
#   'Marden at Stanley',
#   'Boyd at Bitton',
#   'Avon at Bathford',
#   'Avon at Bath ultrasonic',
#   'Sherston Avon at Fosseway',
#   'By Brook at Middlehill',
#   'Severn at Bewdley',
#   'Avon at Evesham',
#   'Vyrnwy at Vyrnwy Reservoir',
#   'Sowe at Stoneleigh',
#   'Severn at Montford',
#   'Arrow at Broom',
#   'Teme at Tenbury',
#   'Salwarpe at Harford Hill',
#   'Tern at Walcot',
#   'Bow Brook at Besford Bridge',
#   'Roden at Rodington',
#   'Leadon at Wedderburn Bridge',
#   'Rea Brook at Hookagate',
#   'Avon at Stareton',
#   'Perry at Yeaton',
#   'Severn at Plynlimon flume',
#   'Worfe at Burcote',
#   'Dulas at Rhos-y-pentref',
#   'Frome at Ebley Mill',
#   'Vyrnwy at Llanymynech',
#   'Teme at Knightsford Bridge',
#   'Severn at Saxons Lode',
#   'Dowles Brook at Oak Cottage',
#   'Isbourne at Hinton on the Green',
#   'Tanat at Llanyblodwel',
#   'Tern at Ternhill',
#   'Dene at Wellesbourne',
#   'Leam at Princes Drive Weir',
#   'Bailey Brook at Ternhill',
#   'Severn at Haw Bridge',
#   'Potford Brook at Sandyford Bridge',
#   'Stour (Worcs) at Prestwood Hospital',
#   'Severn at Dolwen',
#   'Severn at Buildwas',
#   'Hadley Brook at Wards Bridge',
#   'Wye at Belmont',
#   'Wye at Erwood',
#   'Wye at Cefn Brwyn',
#   'Arrow at Titley Mill',
#   'Lugg at Byton',
#   'Ithon at Disserth',
#   'Frome at Yarkhill',
#   'Lugg at Butts Bridge',
#   'Wye at Redbrook',
#   'Llynfi at Three Cocks',
#   'Wye at Ddol Farm',
#   'Monnow at Grosmont',
#   'Elan at Caban Dam',
#   'Usk at Chainbridge',
#   'Ebbw at Rhiwderin',
#   'Senni at Pont-Hen-Hafod',
#   'Grwyne at Millbrook',
#   'Yscir at Pont-Ar-Yscir',
#   'Cynon at Abercynon',
#   'Taff at Pontypridd',
#   'Rhondda at Trehafod',
#   'Taff at Fiddlers Elbow',
#   'Rhymney at Llanedeyrn',
#   'Ely at St Fagans',
#   'Ogmore at Bridgend',
#   'Neath at Resolven',
#   'Mellte at Pontneddfechan',
#   'Dulais at Cilfrew',
#   'Ewenny at Keepers Lodge',
#   'Hepste at Esgair Carnau',
#   'Afan at Marcroft Weir',
#   'Tawe at Ynystanglws',
#   'Cothi at Felin Mynachdy',
#   'Taf at Clog-y-Fran',
#   'Bran at Llandovery',
#   'Gwili at Glangwili',
#   'Tywi at Capel Dewi',
#   'Twrch at Ddol Las',
#   'Ness at Ness-side',
#   'Enrick at Mill of Tore',
#   'Western Cleddau at Prendergast Mill',
#   'Eastern Cleddau at Canaston Bridge',
#   'Teifi at Glanteifi',
#   'Ystwyth at Pont Llolwyn',
#   'Ystwyth at Cwm Ystwyth',
#   'Dyfi at Dyfi Bridge',
#   'Dysynni at Pont-y-Garth',
#   'Leri at Dolybont',
#   'Glaslyn at Beddgelert',
#   'Gwyrfai at Bontnewydd',
#   'Erch at Pencaenewydd',
#   'Seiont at Peblig Mill',
#   'Dwyfor at Garndolbenmaen',
#   'Peris at Nant Peris',
#   'Clwyd at Pont-y-Cambwll',
#   'Wheeler at Bodfari',
#   'Elwy at Pont-y-Gwyddel',
#   'Conwy at Cwmlanerch',
#   'Dee at Bala',
#   'Ceiriog at Brynkinalt Weir',
#   'Alwen at Druid',
#   'Alyn at Pont-y-Capel',
#   'Gelyn at Cynefail',
#   'Dee at Manley Hall',
#   'Dee at New Inn',
#   'Clywedog at Bowling Bank',
#   'Dee at Chester Suspension Bridge',
#   'Weaver at Ashbrook',
#   'Dane at Rudheath',
#   'Wistaston Brook at Marshfield Bridge',
#   'Weaver at Audlem',
#   'Gowy at Bridge Trafford',
#   'Irwell at Adelphi Weir',
#   'Mersey at Ashton Weir',
#   'Bollin at Wilmslow',
#   'Etherow at Compstall',
#   'Goyt at Marple Bridge',
#   'Roch at Blackford Bridge',
#   'Tame at Portwood',
#   'Sankey Brook at Causey Bridges',
#   'Alt at Kirkby',
#   'Irk at Collyhurst Weir',
#   'Douglas at Wanes Blades Bridge',
#   'Findhorn at Shenachie',
#   'Findhorn at Forres',
#   'Lossie at Sheriffmills',
#   'Divie at Dunphail',
#   'Lossie at Torwinny',
#   'Ribble at Samlesbury',
#   'Calder at Whalley Weir',
#   'Ribble at Henthorn',
#   'Hodder at Hodder Place',
#   'Darwen at Blue Bridge',
#   'Wyre at St Michaels',
#   'Lune at Caton',
#   'Lune at Killington',
#   'Brock at upstream of A6',
#   'Wenning at Wennington',
#   'Conder at Galgate',
#   'Lune at Lunes Bridge',
#   'Kent at Sedgwick',
#   'Sprint at Sprint Mill',
#   'Leven at Newby Bridge',
#   'Mint at Mint Bridge',
#   'Brathay at Jeffy Knotts',
#   'Keer at High Keer Weir',
#   'Duddon at Duddon Hall',
#   'Ehen at Braystones',
#   'Calder at Calder Hall',
#   'Esk at Cropple How',
#   'Derwent at Ouse Bridge',
#   'Cocker at Southwaite Bridge',
#   'Ellen at Bullgill',
#   'Eamont at Udford',
#   'Eden at Temple Sowerby',
#   'Eden at Sheepmount',
#   'Irthing at Greenholme',
#   'Coal Burn at Coalburn',
#   'Eden at Kirkby Stephen',
#   'Esk at Canonbie',
#   'Liddel Water at Rowanburnfoot',
#   'Kirtle Water at Mossknowe',
#   'Annan at Brydekirk',
#   'Kinnel Water at Redhall',
#   'Annan at Woodfoot',
#   'Nith at Friars Carse',
#   'Nith at Hall Bridge',
#   'Scar Water at Capenoch',
#   'Cluden Water at Fiddlers Ford',
#   'Nith at Drumlanrig',
#   'Urr at Dalbeattie',
#   'Dee at Glenlochar',
#   'White Laggan Burn at Loch Dee',
#   'Green Burn at Loch Dee',
#   'Dargall Lane at Loch Dee',
#   'Blackwater at Loch Dee',
#   'Avon at Delnashaugh',
#   'Spey at Boat of Garten',
#   'Spey at Boat o Brig',
#   'Dulnain at Balnaan Bridge',
#   'Livet at Minmore',
#   'Feshie at Feshie Bridge',
#   'Cree at Newton Stewart',
#   'Luce at Airyhemming',
#   'Bladnoch at Low Malzie',
#   'Water of Minnoch at Minnoch Bridge',
#   'Water of Fleet at Rusko',
#   'Girvan at Robstone',
#   'Stinchar at Balnowlart',
#   'Ayr at Catrine',
#   'Lugar Water at Langholm',
#   'Ayr at Mainholm',
#   'Lugton Water at Eglinton Castle',
#   'Garnock at Kilwinning',
#   'Irvine at Newmilns',
#   'Irvine at Glenfield',
#   'Kelvin at Killermont',
#   'Clyde at Sills of Clyde',
#   'Clyde at Blairston',
#   'Rotten Calder Water at Redlees',
#   'Nethan at Kirkmuirhill',
#   'White Cart Water at Hawkhead',
#   'Clyde at Daldowie',
#   'Avon Water at Fairholm',
#   'Luggie Water at Condorrat',
#   'Black Cart Water at Milliken Park',
#   'Clyde at Tulliford Mill',
#   'North Calder Water at Calderpark',
#   'Glazert Water at Milton of Campsie',
#   'Duneaton at Maidencots',
#   'Allander Water at Milngavie',
#   'White Cart Water at Overlee',
#   'Leven at Linnbrane',
#   'Endrick Water at Gaidrew',
#   'Falloch at Glen Falloch',
#   'Luss Water at Luss',
#   'Carradale at Dippen',
#   'Linne nam Beathach at Victoria Bridge',
#   'Orchy at Glen Orchy',
#   'Lochy at Inverlochy',
#   "Abhainn a' Bhealaich at Braevallich",
#   'Nevis at Claggan',
#   'Deveron at Muiresk',
#   'Isla at Grange',
#   'Bogie at Redcraig',
#   'Allt Deveron at Cabrach',
#   'Shiel at Shielfoot',
#   'Carron at New Kelso',
#   'Ewe at Poolewe',
#   'Inver at Little Assynt',
#   'Halladale at Halladale',
#   'Naver at Apigill',
#   'Strathmore at Allnabad',
#   'Thurso at Halkirk'],
#  'BasicInputTimeSeries': {'fields': ['Year_Mnth_Day',
#    'basin_id',
#    'prcp(mm/day)',
#    'tmean(C)',
#    'QObs(mm/d)'],
#   'index_fields': ['basin_id', 'date'],
#   'initial_date': '1989-10-02T00:00:00.000000',
#   'end_date': '2008-12-31T00:00:00.000000',
#   'time_delta': '1000',
#   'time_steps': 7031},
#  'BasicInputStaticProps': {'fields': ['gauge_id',
#    'p_mean',
#    'pet_mean',
#    'p_seasonality',
#    'frac_snow',
#    'aridity',
#    'high_prec_freq',
#    'high_prec_dur',
#    'high_prec_timing',
#    'low_prec_freq',
#    'low_prec_dur',
#    'low_prec_timing',
#    'q_mean',
#    'runoff_ratio',
#    'slope_fdc',
#    'baseflow_index',
#    'stream_elas',
#    'Q5',
#    'Q95',
#    'high_q_freq',
#    'high_q_dur',
#    'low_q_freq',
#    'low_q_dur',
#    'zero_q_freq',
#    'hfd_mean',
#    'gauge_lat',
#    'gauge_lon',
#    'elev_mean',
#    'area',
#    'dom_land_cover'],
#   'index_fileds': ['gauge_id']},
#  'NpropperTimeStatic': 29}
