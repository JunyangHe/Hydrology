# %%
import numpy as np
import pandas as pd
import os
from pathlib import Path, PosixPath
from tqdm import tqdm
import sys
import glob
import datetime
from typing import List
import json

# %%
CREATE_CSV_FILES = True
CAMELS_COMBINED = True
COMPARE_SOURCES = True
root_path = "/content/gdrive/MyDrive/Colab Datasets/Hydrology/cl"

from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Create csv Files

# %% [markdown]
# ## Read Timeseries Files

# %%
def to_datetime(s):
  date = s.split('-')
  year = int(date[0])
  month = int(date[1])
  day = int(date[2])
  d = datetime.date(year, month, day)
  return d


def read_timeseries_data(data_dir: str):
  files = list(Path(data_dir).glob('*.csv'))
  input = []

  for csv in files:
      file_name = os.path.basename(csv)
      names = file_name.split('.')

      df_input = pd.read_csv(csv, dtype=None)
      df_input['basin_id'] = int(names[0])
      df_input['date'].apply(to_datetime)
      input.append(df_input)

  timeseries_data = pd.concat(input, axis=0, copy=False)

  return timeseries_data

# %%
if CREATE_CSV_FILES:
  timeseries_dir = root_path + "/raw_timeseries/preprocessed"
  timeseries_data = read_timeseries_data(timeseries_dir)
  forcing_data = timeseries_data[['date', 'basin_id', 'precip_cr2met', 'tmean_cr2met']]
  discharge_data = timeseries_data[['date', 'basin_id', 'streamflow_mm']]

  forcing_data.to_csv(root_path + "/forcing_data_cl.csv", index=False)
  discharge_data.to_csv(root_path + "/discharge_data_cl.csv", index=False)

# %% [markdown]
# ## Read Attributes Files

# %%
def read_attributes(data_dir: str):
  attributes = pd.read_csv(data_dir + "/CAMELS_cl_attributes.csv")
  attributes = attributes.astype({"gauge_id": int}, errors='raise')

  return attributes

# %%
if CREATE_CSV_FILES:
  attributes_dir = root_path
  attr = read_attributes(attributes_dir)
  attr.to_csv(root_path + "/attributes_cl.csv", index=False)
  attr

# %% [markdown]
# # Read csv files

# %%
BASIN_COL = 'basin_id'
DATE_COL = 'date'

# %%
# read csvs
attr_p = pd.read_csv(root_path + "/attributes_cl.csv")
discharge_p = pd.read_csv(root_path + "/discharge_data_cl.csv")
forcing_p = pd.read_csv(root_path + "/forcing_data_cl.csv")

# %%
discharge_p
# Out:
#                date  basin_id  streamflow_mm
# 0        1976-07-21   1001001       0.870746
# 1        1976-07-22   1001001       0.863794
# 2        1976-07-23   1001001       0.841200
# 3        1976-07-24   1001001       0.802963
# 4        1976-07-25   1001001       0.782107
# ...             ...       ...            ...
# 9893832  2018-03-05  12930001       1.021117
# 9893833  2018-03-06  12930001       0.949974
# 9893834  2018-03-07  12930001       0.929049
# 9893835  2018-03-08  12930001       0.929049
# 9893836  2018-03-09  12930001       0.929049
#
# [9893837 rows x 3 columns]

# %%
forcing_p
# Out:
#                date  basin_id  precip_cr2met  tmean_cr2met
# 0        1976-07-21   1001001            NaN           NaN
# 1        1976-07-22   1001001            NaN           NaN
# 2        1976-07-23   1001001            NaN           NaN
# 3        1976-07-24   1001001            NaN           NaN
# 4        1976-07-25   1001001            NaN           NaN
# ...             ...       ...            ...           ...
# 9893832  2018-03-05  12930001            NaN           NaN
# 9893833  2018-03-06  12930001            NaN           NaN
# 9893834  2018-03-07  12930001            NaN           NaN
# 9893835  2018-03-08  12930001            NaN           NaN
# 9893836  2018-03-09  12930001            NaN           NaN
#
# [9893837 rows x 4 columns]

# %%
# read csvs
attr_p = pd.read_csv(root_path + "/attributes_cl.csv")
discharge_p = pd.read_csv(root_path + "/discharge_data_cl.csv")
forcing_p = pd.read_csv(root_path + "/forcing_data_cl.csv")

# %%
locs = np.union1d(np.union1d(forcing_p[BASIN_COL], discharge_p[BASIN_COL]), attr_p['gauge_id'])
Nloc = len(locs)

print('Initial Nloc', Nloc)
# Out:
# Initial Nloc 516

# %% [markdown]
# ## Sanity Check

# %%
# Compare precipitation measurement sources
if COMPARE_SOURCES:
  timeseries_dir = root_path + "/raw_timeseries/preprocessed"
  timeseries_data = read_timeseries_data(timeseries_dir)

  # cr2met & chirps comparison
  precip_crch = timeseries_data[['precip_cr2met', 'precip_chirps']].dropna(axis = 0).astype(float)
  n1 = precip_crch.shape[0]
  precip_crch['cr^2'] = precip_crch['precip_cr2met'] ** 2
  precip_crch['ch^2'] = precip_crch['precip_chirps'] ** 2
  precip_crch['crch'] = precip_crch['precip_cr2met'] * precip_crch['precip_chirps']

  numerator1 = n1 * (precip_crch['crch'].sum()) - (precip_crch['precip_cr2met'].sum() * precip_crch['precip_chirps'].sum())
  denominator1 = (n1 * precip_crch['cr^2'].sum() - (precip_crch['precip_cr2met'].sum() ** 2)) * (n1 * precip_crch['ch^2'].sum() - (precip_crch['precip_chirps'].sum() ** 2))
  r1 = numerator1/(denominator1**0.5)

  print('Correlation coefficient for cr2met and chirps is:', r1)


  # cr2met & tmpa comparison
  precip_crtm = timeseries_data[['precip_cr2met', 'precip_tmpa']].dropna(axis = 0).astype(float)
  n2 = precip_crtm.shape[0]
  precip_crtm['cr^2'] = precip_crtm['precip_cr2met'] ** 2
  precip_crtm['tm^2'] = precip_crtm['precip_tmpa'] ** 2
  precip_crtm['crtm'] = precip_crtm['precip_cr2met'] * precip_crtm['precip_tmpa']

  numerator2 = n2 * (precip_crtm['crtm'].sum()) - (precip_crtm['precip_cr2met'].sum() * precip_crtm['precip_tmpa'].sum())
  denominator2 = (n2 * precip_crtm['cr^2'].sum() - (precip_crtm['precip_cr2met'].sum() ** 2)) * (n2 * precip_crtm['tm^2'].sum() - (precip_crtm['precip_tmpa'].sum() ** 2))
  r2 = numerator2/(denominator2**0.5)

  print('Correlation coefficient for cr2met and tmpa is:', r2)

  # cr2met & mswep comparison
  precip_crms = timeseries_data[['precip_cr2met', 'precip_mswep']].dropna(axis = 0).astype(float)
  n3 = precip_crms.shape[0]
  precip_crms['cr^2'] = precip_crms['precip_cr2met'] ** 2
  precip_crms['ms^2'] = precip_crms['precip_mswep'] ** 2
  precip_crms['crms'] = precip_crms['precip_cr2met'] * precip_crms['precip_mswep']

  numerator3 = n3 * (precip_crms['crms'].sum()) - (precip_crms['precip_cr2met'].sum() * precip_crms['precip_mswep'].sum())
  denominator3 = (n3 * precip_crms['cr^2'].sum() - (precip_crms['precip_cr2met'].sum() ** 2)) * (n3 * precip_crms['ms^2'].sum() - (precip_crms['precip_mswep'].sum() ** 2))
  r3 = numerator3/(denominator3**0.5)

  print('Correlation coefficient for cr2met and mswep is:', r3)
# Out:
# Correlation coefficient for cr2met and chirps is: 0.5735014972080532
# Correlation coefficient for cr2met and tmpa is: 0.5930272204337096
# Correlation coefficient for cr2met and mswep is: 0.7024249966306338

# %%
def remove_basins_globally(basins: List[int]):
  global discharge_p
  global forcing_p
  global attr_p
  global locs
  global Nloc

  print("removing", basins)

  discharge_p.drop(discharge_p[discharge_p[BASIN_COL].isin(basins)].index, inplace=True, errors='ignore')
  forcing_p.drop(forcing_p[forcing_p[BASIN_COL].isin(basins)].index, inplace=True, errors='ignore')
  attr_p.drop(attr_p[attr_p['gauge_id'].isin(basins)].index, inplace=True, errors='ignore')

  locs = np.setdiff1d(locs, basins)
  Nloc = len(locs)
  print('new Nloc', Nloc)

# %%
intersect = np.intersect1d(np.intersect1d(forcing_p[BASIN_COL], discharge_p[BASIN_COL]), attr_p['gauge_id'])

diff = np.setdiff1d(locs, intersect)
print("diff", diff)

if len(diff) > 0:
  remove_basins_globally(diff)
# Out:
# diff []

# %%
def find_time_range(df: pd.DataFrame):
  groups = df[[BASIN_COL, DATE_COL]].groupby([BASIN_COL])
  counts = groups.count()

  abnormal_cols = counts[counts[DATE_COL] < 1000].index.values

  if len(abnormal_cols) > 0:
    print('abnormal cols', abnormal_cols)
    remove_basins_globally(abnormal_cols)
    groups = df[[BASIN_COL, DATE_COL]].groupby([BASIN_COL])

  mins = groups.min()
  maxs = groups.max()

  min_d  = np.max(mins.values)
  max_d  = np.min(maxs.values)
  print("range", min_d, max_d)

  return min_d, max_d

# %%
min1, max1 = find_time_range(discharge_p)
min2, max2 = find_time_range(forcing_p)
# Out:
# range 1979-01-01 2016-12-31
# range 1979-01-01 2016-12-31

# %%
InitialDate = max(min1, min2)
InitialDate = "1989-10-02"
print("InitialDate ", InitialDate)

EndDate = min(max1, max2)
EndDate = "2008-12-31"
print("EndDate ", EndDate)
# Out:
# InitialDate  1989-10-02
# EndDate  2008-12-31

# %%
# filter data sets based on the InitialDate and EndDate
discharge_p.drop(discharge_p[(discharge_p[DATE_COL] < InitialDate) | (discharge_p[DATE_COL] > EndDate)].index,
                 inplace=True, errors='ignore')
forcing_p.drop(forcing_p[(forcing_p[DATE_COL] < InitialDate) | (forcing_p[DATE_COL] > EndDate)].index,
                 inplace=True, errors='ignore')

# %% [markdown]
# ## Dynamic Data

# %%
input_p = forcing_p.merge(discharge_p, on=[BASIN_COL, DATE_COL], copy=True, validate="1:1")
input_p
# Out:
#                date  basin_id  precip_cr2met  tmean_cr2met  streamflow_mm
# 0        1989-10-02   1001001       0.000000      3.767656       0.867270
# 1        1989-10-03   1001001       0.000000      4.097199       0.865532
# 2        1989-10-04   1001001       0.000000      3.866711       0.869008
# 3        1989-10-05   1001001       0.000000      3.225777       0.872484
# 4        1989-10-06   1001001       0.000000      2.435284       0.872484
# ...             ...       ...            ...           ...            ...
# 3627991  2008-12-27  12930001       0.958708      2.528415       3.410700
# 3627992  2008-12-28  12930001       1.995861      2.863661       3.816636
# 3627993  2008-12-29  12930001       0.975161      5.851183       4.172353
# 3627994  2008-12-30  12930001       1.066232      2.933977       4.226757
# 3627995  2008-12-31  12930001       1.037208      5.933977       6.528456
#
# [3627996 rows x 5 columns]

# %%
input_p.rename(columns = {'date':'Year_Mnth_Day', 'basin_id':'basin_id', 'precip_cr2met':'prcp(mm/day)', 'tmean_cr2met':'tmean(C)', 'streamflow_mm':'QObs(mm/d)'}, inplace = True)

# %%
input_p.sort_values(["Year_Mnth_Day", BASIN_COL], inplace=True, ignore_index=True)
input_p = input_p[~(input_p['Year_Mnth_Day'] < '1989-10-02')]
input_p = input_p[~(input_p['Year_Mnth_Day'] > '2008-12-31')]
input_p['Year_Mnth_Day'] = pd.to_datetime(input_p['Year_Mnth_Day'], format='%Y-%m-%d')

# %%
input_p['prcp(mm/day)'] = input_p['prcp(mm/day)'].fillna(input_p['prcp(mm/day)'].mean())
input_p['tmean(C)'] = input_p['tmean(C)'].fillna(input_p['tmean(C)'].mean())
input_p['QObs(mm/d)'] = input_p['QObs(mm/d)'].fillna(input_p['QObs(mm/d)'].mean())

# %%
assert len(input_p) == len (forcing_p) and len(input_p) == len (discharge_p)

# %%
BasicInputTimeSeries = input_p.to_numpy()

# %%
print(BasicInputTimeSeries.shape)
print(BasicInputTimeSeries[0])
# Out:
# (3627996, 5)
# [Timestamp('1989-10-02 00:00:00') 1001001 0.0 3.7676558 0.86726993]

# %% [markdown]
# ## Static Data

# %%
INVALID_ATTR= []

if CAMELS_COMBINED:
  INVALID_ATTR = [
      'gauge_name', 'p_mean_tmpa', 'gauge_record_start', 'gauge_record_end', 'gauge_n_obs', 'elev_gauge', 'record_period_start', 'record_period_end', 'n_obs', 'elev_med', 'elev_max', 'elev_min',
      'nested_inner', 'nested_outer', 'lc_barren', 'lc_glacier', 'p_mean_chirps', 'p_mean_mswep', 'location_type', 'geol_class_1st', 'geol_class_1st_frac',
      'geol_class_2nd', 'aridity_chirps', 'aridity_mswep', 'aridity_tmpa', 'p_seasonality_chirps', 'p_seasonality_mswep', 'p_seasonality_tmpa', 'frac_snow_chirps',
      'frac_snow_mswep', 'frac_snow_tmpa', 'high_prec_freq_chirps', 'high_prec_freq_mswep', 'high_prec_freq_tmpa', 'geol_class_2nd_frac', 'carb_rocks_frac', 'crop_frac',
      'grass_frac', 'high_prec_dur_chirps', 'high_prec_dur_mswep', 'high_prec_dur_tmpa', 'high_prec_timing_chirps', 'high_prec_timing_mswep', 'high_prec_timing_tmpa',
      'low_prec_freq_chirps', 'low_prec_freq_mswep', 'low_prec_freq_tmpa', 'low_prec_dur_chirps', 'low_prec_dur_mswep', 'low_prec_dur_tmpa', 'low_prec_timing_chirps',
      'low_prec_timing_mswep', 'low_prec_timing_tmpa', 'runoff_ratio_chirps', 'runoff_ratio_mswep', 'runoff_ratio_tmpa', 'stream_elas_chirps', 'stream_elas_mswep',
      'stream_elas_tmpa', 'big_dam', 'shrub_frac', 'wet_frac', 'imp_frac', 'barren_frac', 'snow_frac', 'fp_nf_index', 'land_cover_missing', 'glaciers_area', 'glaciers_frac',
      'p_mean_spread', 'swe_ratio', 'sur_rights_n', 'sur_rights_flow', 'interv_degree', 'gw_rights_n', 'gw_rights_flow', 'large_dam', 'dom_land_cover_frac', 'forest_frac',
      'slope_mean', 'nf_frac', 'fp_frac'
  ]

# %%
filtered_attr = attr_p.copy()
filtered_attr.drop(INVALID_ATTR, axis=1, inplace=True, errors='ignore')
filtered_attr.dtypes
# Out:
# gauge_id                     int64
# gauge_lat                  float64
# gauge_lon                  float64
# area                       float64
# elev_mean                  float64
# dom_land_cover              object
# p_mean_cr2met              float64
# pet_mean                   float64
# aridity_cr2met             float64
# p_seasonality_cr2met       float64
# frac_snow_cr2met           float64
# high_prec_freq_cr2met      float64
# high_prec_dur_cr2met       float64
# high_prec_timing_cr2met     object
# low_prec_freq_cr2met       float64
# low_prec_dur_cr2met        float64
# low_prec_timing_cr2met      object
# q_mean                     float64
# runoff_ratio_cr2met        float64
# stream_elas_cr2met         float64
# slope_fdc                  float64
# baseflow_index             float64
# hfd_mean                   float64
# Q95                        float64
# Q5                         float64
# high_q_freq                float64
# high_q_dur                 float64
# low_q_freq                 float64
# low_q_dur                  float64
# zero_q_freq                float64
# dtype: object

# %%
# Re-order Columns
filtered_attr = filtered_attr[['gauge_id', 'p_mean_cr2met', 'pet_mean', 'p_seasonality_cr2met', 'frac_snow_cr2met', 'aridity_cr2met',
                               'high_prec_freq_cr2met', 'high_prec_dur_cr2met', 'high_prec_timing_cr2met', 'low_prec_freq_cr2met',
                               'low_prec_dur_cr2met', 'low_prec_timing_cr2met', 'q_mean', 'runoff_ratio_cr2met', 'slope_fdc',
                               'baseflow_index', 'stream_elas_cr2met', 'Q5', 'Q95', 'high_q_freq', 'high_q_dur', 'low_q_freq',
                               'low_q_dur', 'zero_q_freq', 'hfd_mean', 'gauge_lat', 'gauge_lon', 'elev_mean', 'area', 'dom_land_cover']]

# %%
assert len(filtered_attr) == Nloc

# %%
# Categorical variable encoding
cols = filtered_attr.columns
categorical_cols = filtered_attr.select_dtypes(exclude = ['number']).columns

for cat_col in categorical_cols:
  num_cat = filtered_attr[cat_col].value_counts().count()
  filtered_attr[cat_col] = (filtered_attr[cat_col].astype('category').cat.codes)/num_cat

  print('Processed ', cat_col)
# Out:
# Processed  high_prec_timing_cr2met
# Processed  low_prec_timing_cr2met
# Processed  dom_land_cover

# %%
filtered_attr.isna().sum()
# Out:
# gauge_id                     0
# p_mean_cr2met                0
# pet_mean                     0
# p_seasonality_cr2met         0
# frac_snow_cr2met             0
# aridity_cr2met               0
# high_prec_freq_cr2met        0
# high_prec_dur_cr2met         0
# high_prec_timing_cr2met      0
# low_prec_freq_cr2met         0
# low_prec_dur_cr2met          0
# low_prec_timing_cr2met       0
# q_mean                     278
# runoff_ratio_cr2met        278
# slope_fdc                  278
# baseflow_index             278
# stream_elas_cr2met         278
# Q5                         278
# Q95                        278
# high_q_freq                278
# high_q_dur                 278
# low_q_freq                 278
# low_q_dur                  278
# zero_q_freq                278
# hfd_mean                   278
# gauge_lat                    0
# gauge_lon                    0
# elev_mean                    0
# area                         0
# dom_land_cover               0
# dtype: int64

# %%
# Remove NaN values
nan_cols = [col for col in filtered_attr.columns if filtered_attr.isna().sum()[col] > 0]
print(nan_cols)

for nan_col in nan_cols:
  filtered_attr[nan_col] = filtered_attr[nan_col].fillna(filtered_attr[nan_col].mean())
# Out:
# ['q_mean', 'runoff_ratio_cr2met', 'slope_fdc', 'baseflow_index', 'stream_elas_cr2met', 'Q5', 'Q95', 'high_q_freq', 'high_q_dur', 'low_q_freq', 'low_q_dur', 'zero_q_freq', 'hfd_mean']

# %%
BasicInputStaticProps = filtered_attr.to_numpy()
NpropperTimeStatic = len(filtered_attr.columns) - 1
print('NpropperTimeStatic', NpropperTimeStatic)
print(filtered_attr.columns)
# Out:
# NpropperTimeStatic 29
# Index(['gauge_id', 'p_mean_cr2met', 'pet_mean', 'p_seasonality_cr2met',
#        'frac_snow_cr2met', 'aridity_cr2met', 'high_prec_freq_cr2met',
#        'high_prec_dur_cr2met', 'high_prec_timing_cr2met',
#        'low_prec_freq_cr2met', 'low_prec_dur_cr2met', 'low_prec_timing_cr2met',
#        'q_mean', 'runoff_ratio_cr2met', 'slope_fdc', 'baseflow_index',
#        'stream_elas_cr2met', 'Q5', 'Q95', 'high_q_freq', 'high_q_dur',
#        'low_q_freq', 'low_q_dur', 'zero_q_freq', 'hfd_mean', 'gauge_lat',
#        'gauge_lon', 'elev_mean', 'area', 'dom_land_cover'],
#       dtype='object')

# %% [markdown]
# # Save Datasets

# %%
if CAMELS_COMBINED:
  input_p.to_csv(root_path + "/BasicInputTimeSeries_cl_combined.csv")
  filtered_attr.to_csv(root_path + "/BasicInputStaticProps_cl_combined.csv")
  np.save(root_path + "/BasicInputTimeSeries_cl_combined", BasicInputTimeSeries)
  np.save(root_path + "/BasicInputStaticProps_cl_combined", BasicInputStaticProps)

else:
  input_p.to_csv(root_path + "/BasicInputTimeSeries_cl.csv")
  filtered_attr.to_csv(root_path + "/BasicInputStaticProps_cl.csv")
  np.save(root_path + "/BasicInputTimeSeries_cl", BasicInputTimeSeries)
  np.save(root_path + "/BasicInputStaticProps_cl", BasicInputStaticProps)

# %%
from datetime import datetime
EndDate = datetime.strptime(EndDate, '%Y-%m-%d')
EndDate = np.datetime64(EndDate)
InitialDate = datetime.strptime(InitialDate, '%Y-%m-%d')
InitialDate = np.datetime64(InitialDate)

print(type(EndDate))
int(((EndDate-InitialDate + np.timedelta64(1, 'D'))/np.timedelta64(1, 'D')))
# Out:
# <class 'numpy.datetime64'>
# 7031

# %%
meta_data = {
    'Nloc': Nloc,
    'locs': locs.tolist(),
    'loc_names': attr_p['gauge_name'].tolist(),
    'BasicInputTimeSeries':{
      'fields': input_p.columns.values.tolist(),
      'index_fields': [BASIN_COL, DATE_COL],
      'initial_date': str(InitialDate),
      'end_date': str(EndDate),
      'time_delta': str(BasicInputTimeSeries[1, 1] - BasicInputTimeSeries[0, 1]),
      'time_steps': int(((EndDate-InitialDate + np.timedelta64(1, 'D'))/np.timedelta64(1, 'D'))),
    },
    'BasicInputStaticProps': {
        'fields': filtered_attr.columns.values.tolist(),
        'index_fileds': ['gauge_id'],
    },
    'NpropperTimeStatic': len(filtered_attr.columns) - 1
}

# %%
if CAMELS_COMBINED:
  with open(root_path + "/metadata_cl_combined.json", 'w') as outfile:
    json.dump(meta_data, outfile, indent='\t')

else:
  with open(root_path + "/metadata_cl.json", 'w') as outfile:
    json.dump(meta_data, outfile, indent='\t')

# %%
BasicInputTimeSeries
# Out:
# array([[Timestamp('1989-10-02 00:00:00'), 1001001, 0.0, 3.7676558,
#         0.86726993],
#        [Timestamp('1989-10-02 00:00:00'), 1001002, 0.0, 3.7481775,
#         0.14062566],
#        [Timestamp('1989-10-02 00:00:00'), 1001003, 0.0, 4.146216,
#         0.018687354],
#        ...,
#        [Timestamp('2008-12-31 00:00:00'), 12876004, 0.55648845,
#         7.5504074, 2.4411029994031685],
#        [Timestamp('2008-12-31 00:00:00'), 12878001, 0.64957577,
#         7.7898774, 0.5822323],
#        [Timestamp('2008-12-31 00:00:00'), 12930001, 1.0372078, 5.933977,
#         6.5284557]], dtype=object)

# %%
type(BasicInputTimeSeries)
# Out:
# numpy.ndarray

# %%
str(InitialDate)
# Out:
# '1989-10-02T00:00:00.000000'

# %%
str(BasicInputTimeSeries[1, 1] - BasicInputTimeSeries[0, 1])
# Out:
# '1'

# %%
meta_data
# Out:
# {'Nloc': 516,
#  'locs': [1001001,
#   1001002,
#   1001003,
#   1020002,
#   1020003,
#   1021001,
#   1021002,
#   1041002,
#   1044001,
#   1050002,
#   1050004,
#   1201001,
#   1201003,
#   1201005,
#   1210001,
#   1211001,
#   1300009,
#   1310002,
#   1410004,
#   1502002,
#   1502008,
#   1610002,
#   1610004,
#   1730001,
#   1730002,
#   1730003,
#   1730007,
#   1730012,
#   2101001,
#   2103001,
#   2103002,
#   2103003,
#   2103014,
#   2104002,
#   2104003,
#   2104013,
#   2105001,
#   2105002,
#   2105005,
#   2105007,
#   2110001,
#   2110002,
#   2110004,
#   2110031,
#   2112005,
#   2112006,
#   2112007,
#   2113001,
#   2120001,
#   2510001,
#   3022001,
#   3041001,
#   3041002,
#   3041003,
#   3041004,
#   3041005,
#   3050001,
#   3404001,
#   3414001,
#   3421001,
#   3430001,
#   3430002,
#   3430003,
#   3431001,
#   3434001,
#   3434003,
#   3450001,
#   3453001,
#   3802001,
#   3804002,
#   3806001,
#   3814001,
#   3814003,
#   3815001,
#   3815002,
#   3820001,
#   3820002,
#   3820003,
#   3825001,
#   3826001,
#   4301002,
#   4302001,
#   4306001,
#   4308001,
#   4311001,
#   4313001,
#   4314001,
#   4314002,
#   4320001,
#   4323001,
#   4335001,
#   4400001,
#   4501001,
#   4501002,
#   4502001,
#   4502002,
#   4503001,
#   4506002,
#   4511001,
#   4511002,
#   4512001,
#   4513001,
#   4514001,
#   4515001,
#   4515002,
#   4516001,
#   4520001,
#   4522001,
#   4522002,
#   4523001,
#   4523002,
#   4530001,
#   4531001,
#   4531002,
#   4532001,
#   4533002,
#   4534001,
#   4535002,
#   4537001,
#   4540001,
#   4540002,
#   4550003,
#   4556001,
#   4557002,
#   4558001,
#   4703001,
#   4703002,
#   4704001,
#   4704002,
#   4711001,
#   4712001,
#   4714001,
#   4716001,
#   4716004,
#   4721001,
#   4723001,
#   4726001,
#   4730001,
#   4810001,
#   4810005,
#   4810006,
#   5100001,
#   5101001,
#   5101002,
#   5110002,
#   5120001,
#   5200001,
#   5221001,
#   5221002,
#   5320001,
#   5401002,
#   5401003,
#   5402001,
#   5402015,
#   5403002,
#   5403003,
#   5405001,
#   5406001,
#   5406002,
#   5410001,
#   5410002,
#   5410005,
#   5411001,
#   5411002,
#   5414001,
#   5415002,
#   5420002,
#   5421001,
#   5421002,
#   5422001,
#   5423002,
#   5423003,
#   5423004,
#   5423005,
#   5423006,
#   5427003,
#   5701001,
#   5701002,
#   5702001,
#   5703006,
#   5704002,
#   5705001,
#   5706001,
#   5707002,
#   5710001,
#   5715001,
#   5716001,
#   5720001,
#   5721001,
#   5721016,
#   5722001,
#   5722002,
#   5730005,
#   5730008,
#   5734001,
#   5737002,
#   5741001,
#   5746001,
#   5748001,
#   6000003,
#   6002001,
#   6003001,
#   6006001,
#   6008005,
#   6011001,
#   6013001,
#   6015001,
#   6018001,
#   6019003,
#   6025001,
#   6027001,
#   6028001,
#   6033001,
#   6033011,
#   6034001,
#   6034022,
#   6034023,
#   6035001,
#   6043001,
#   6132001,
#   7102001,
#   7102005,
#   7103001,
#   7104001,
#   7104002,
#   7112001,
#   7115001,
#   7116001,
#   7123001,
#   7200002,
#   7300001,
#   7303000,
#   7306001,
#   7308001,
#   7308002,
#   7317003,
#   7317005,
#   7320003,
#   7321002,
#   7322001,
#   7330001,
#   7331001,
#   7332001,
#   7335001,
#   7335002,
#   7336001,
#   7339001,
#   7340001,
#   7341001,
#   7343001,
#   7350001,
#   7350002,
#   7350003,
#   7351001,
#   7354001,
#   7354002,
#   7355001,
#   7355002,
#   7355003,
#   7357002,
#   7358001,
#   7359001,
#   7372001,
#   7374001,
#   7379001,
#   7379002,
#   7381001,
#   7383001,
#   7400001,
#   8104001,
#   8105001,
#   8106001,
#   8106002,
#   8112001,
#   8114001,
#   8115001,
#   8117001,
#   8117004,
#   8117005,
#   8117006,
#   8117008,
#   8118001,
#   8123001,
#   8124001,
#   8124002,
#   8130001,
#   8130002,
#   8132001,
#   8133001,
#   8134002,
#   8134003,
#   8135002,
#   8140002,
#   8141001,
#   8144001,
#   8210003,
#   8220001,
#   8220008,
#   8220009,
#   8220010,
#   8304001,
#   8307002,
#   8308000,
#   8312000,
#   8312001,
#   8313000,
#   8313001,
#   8316002,
#   8317001,
#   8317002,
#   8317004,
#   8317005,
#   8319001,
#   8323001,
#   8323002,
#   8324002,
#   8330001,
#   8332001,
#   8334001,
#   8342001,
#   8343001,
#   8350001,
#   8351001,
#   8356001,
#   8358001,
#   8362001,
#   8366002,
#   8372002,
#   8376001,
#   8380001,
#   8380006,
#   8381003,
#   8383001,
#   8385001,
#   8386001,
#   8393002,
#   8394001,
#   8430001,
#   8530001,
#   8700002,
#   8700003,
#   8720001,
#   8820001,
#   8821001,
#   8821002,
#   8821003,
#   8821006,
#   8822001,
#   8822002,
#   8910001,
#   9101001,
#   9101002,
#   9102001,
#   9104001,
#   9104002,
#   9106001,
#   9107001,
#   9107002,
#   9111001,
#   9113001,
#   9116001,
#   9122002,
#   9123001,
#   9126001,
#   9127001,
#   9129002,
#   9131001,
#   9134001,
#   9135001,
#   9140001,
#   9400000,
#   9402001,
#   9404001,
#   9405001,
#   9412001,
#   9414001,
#   9416001,
#   9420001,
#   9423001,
#   9433001,
#   9434001,
#   9436001,
#   9437002,
#   10100002,
#   10100006,
#   10102001,
#   10111001,
#   10121001,
#   10122001,
#   10122002,
#   10122003,
#   10133000,
#   10134001,
#   10137001,
#   10140001,
#   10142003,
#   10304001,
#   10305001,
#   10306001,
#   10311001,
#   10313001,
#   10322003,
#   10327001,
#   10328001,
#   10340001,
#   10343001,
#   10343002,
#   10344003,
#   10344004,
#   10351001,
#   10356001,
#   10362001,
#   10363002,
#   10364001,
#   10401001,
#   10405001,
#   10405002,
#   10405005,
#   10411002,
#   10411003,
#   10414001,
#   10431000,
#   10431001,
#   10432002,
#   10432003,
#   10440000,
#   10503001,
#   10514001,
#   10520001,
#   10523002,
#   10683002,
#   10701002,
#   10702002,
#   10704002,
#   11020004,
#   11040001,
#   11130001,
#   11141001,
#   11143001,
#   11143002,
#   11147001,
#   11147002,
#   11151001,
#   11302001,
#   11307001,
#   11308001,
#   11310001,
#   11310002,
#   11310003,
#   11312001,
#   11314001,
#   11315001,
#   11316001,
#   11317001,
#   11335002,
#   11337001,
#   11342001,
#   11405001,
#   11500002,
#   11504001,
#   11505001,
#   11514001,
#   11520002,
#   11521001,
#   11530000,
#   11532000,
#   11536001,
#   11536004,
#   11542001,
#   11545000,
#   11701001,
#   11710000,
#   11711000,
#   12280002,
#   12284002,
#   12284003,
#   12284005,
#   12284006,
#   12284007,
#   12285001,
#   12285003,
#   12286002,
#   12287001,
#   12288002,
#   12288003,
#   12288004,
#   12289001,
#   12289002,
#   12289003,
#   12291001,
#   12400003,
#   12400004,
#   12448001,
#   12452001,
#   12561001,
#   12563001,
#   12582001,
#   12585001,
#   12585002,
#   12586001,
#   12600001,
#   12622001,
#   12660001,
#   12802001,
#   12805001,
#   12806001,
#   12820001,
#   12825002,
#   12861001,
#   12863002,
#   12865001,
#   12872001,
#   12876001,
#   12876004,
#   12878001,
#   12930001],
#  'loc_names': ['Rio Caquena En Nacimiento',
#   'Rio Caquena En Vertedero',
#   'Rio Colpacagua En Desembocadura',
#   'Rio Desaguadero Cotacotani',
#   'Rio Lauca En Estancia El Lago',
#   'Rio Lauca En Japu (O En El Limite)',
#   'Rio Guallatire En Guallatire',
#   'Rio Isluga En Bocatoma',
#   'Rio Cancosa En El Tambo',
#   'Rio Piga En Collacagua',
#   'Rio Collacagua En Peablanca',
#   'Rio Colpitas En Alcerreca',
#   'Rio Lluta En Alcerreca',
#   'Rio Caracarani En Humapalca',
#   'Rio Lluta En Tocontasi',
#   'Rio Lluta En Panamericana',
#   'Rio Ticnamar En Angostura',
#   'Rio San Jose En Ausipar',
#   'Rio Codpa En Cala-Cala',
#   'Rio Camarones En Conanoxa',
#   'Rio Camarones En Chilpe',
#   'Quebrada CamiÑA En Altusa',
#   'Q. Camia 3 Km. A. Arriba De Tarcavire',
#   'Rio Coscaya En Pampa Lirima',
#   'Rio Tarapaca En Mina San Juan',
#   'Rio Coscaya En Saitoco',
#   'Q. Tarapaca En Sibaya',
#   'Q. Tarapaca En Laonsana',
#   'Rio Loa Antes Represa Lequena',
#   'Rio San Pedro En Parshall N\\1"',
#   'Rio San Pedro En Parshall N\\2 (Bt. Chilex)"',
#   'Rio San Pedro En Camino Internacional',
#   'Rio Siloli Antes B.T. Fcab',
#   'Rio Loa En Salida Embalse Conchi',
#   'Rio Loa En Alcantarilla Conchi N\\2"',
#   'Rio Loa En Vado Santa Barbara (Doh)',
#   'Rio Salado A. J. Curti',
#   'Rio Salado En Sifon Ayquina',
#   'Rio Salado A. J. Loa',
#   'Rio Toconce Antes Represa Sendos',
#   'Rio Loa En Escorial',
#   'Rio Loa En Yalquincha',
#   'Rio Loa En Finca',
#   'Rio Loa En Angostura',
#   'Rio Loa Antes Zona Agricola Quillagua',
#   'Rio Loa D. J. San Salvador (Chacance)',
#   'Rio Loa D. J. San Salvador-(M. Elena)',
#   'Rio Huatacondo En Copaquire',
#   'Rio Loa En Desembocadura',
#   'Rio San Pedro En Cuchabrachi',
#   'Rio La Ola En Vertedero',
#   'Rio Barros Negros Antes Junta Valle Ancho',
#   'Rio Villalobos En Vertedero',
#   'Rio Valle Ancho Antes  Junta Barros Negros',
#   'Rio Valle Ancho En La Barrera',
#   'Rio Lamas En El Salto',
#   'Rio Astaburuaga En Cono',
#   'Rio Jorquera En Vertedero',
#   'Rio Pulido En Vertedero',
#   'Rio Manflas En Vertedero',
#   'Rio Copiapo En Lautaro',
#   'Rio Copiapo En San Antonio',
#   'Rio Copiapo En Pastillo',
#   'Rio Copiapo En La Puerta',
#   'Rio Copiapo En Mal Paso Aguas Arriba Canal',
#   'Rio Copiapo En Mal Paso Aguas Abajo Canal',
#   'Rio Copiapo En Ciudad De Copiapo',
#   'Rio Copiapo En Angostura',
#   'Rio Conay En Las Lozas',
#   'Rio Transito En Angostura Pinte',
#   'Rio Transito Antes Junta Rio Carmen',
#   'Rio Carmen En San Felix',
#   'Rio Carmen En El Corral',
#   'Rio Carmen En Ramadillas',
#   'Rio Carmen En Pte. La Majada',
#   'Rio Huasco En Algodones',
#   'Rio Huasco En Chepica',
#   'Rio Huasco En Santa Juana',
#   'Rio Huasco En Puente Nicolasa',
#   'Rio Huasco En Huasco Bajo',
#   'Rio La Laguna En Salida Embalse La Laguna',
#   'Rio Toro Antes Junta Rio La Laguna',
#   'Rio Turbio En Huanta',
#   'Rio Turbio En Varillar',
#   'Estero Derecho En Alcohuaz',
#   'Rio Cochiguaz En El PeÑOn',
#   'Rio Claro En Montegrande',
#   'Rio Claro En Rivadavia',
#   'Rio Elqui En Algarrobal',
#   'Rio Elqui En Almendral',
#   'Rio Elqui En La Serena',
#   'Estero Culebron En El Sifon',
#   'Rio Hurtado En San Agustin',
#   'Rio Hurtado En Las Breas',
#   'Rio Hurtado En La Cortadera',
#   'Rio Hurtado En Hurtado',
#   'Rio Hurtado En Angostura De Pangue',
#   'Rio Hurtado En Entrada Embalse Recoleta',
#   'Rio Grande En Las Pegas',
#   'Rio Grande En Las Ramadas',
#   'Rio Tascadero En Desembocadura',
#   'Rio Grande En Cuyano',
#   'Rio Mostazal En Cuestecita',
#   'Rio Mostazal Antes Junta Rio Tulahuencito',
#   'Rio Mostazal En Caren',
#   'Rio Grande En Coipo',
#   'Rio Los Molles En Ojos De Agua',
#   'Rio Rapel En Paloma',
#   'Rio Rapel En Junta',
#   'Rio Grande En Agua Chica',
#   'Rio Grande En Puntilla San Juan',
#   'Rio Cogoti En Fraguita',
#   'Rio Cogoti En Cogoti 18',
#   'Rio Cogoti Entrada Embalse Cogoti',
#   'Rio Combarbala En Ramadillas',
#   'Rio Pama En Valle Hermoso',
#   'Rio Pama Entrada Embalse Cogoti',
#   'Rio Guatulame En Salida Embalse Cogoti',
#   'Rio Guatulame En El Tome',
#   'Rio Grande En Paloma 1',
#   'Rio Guatulame En Desembocadura Embalse La Paloma',
#   'Rio Limari En PeÑOnes Bajos',
#   'Estero Punitaqui En Chalinga',
#   'Estero Punitaqui Antes Junta Rio Limari',
#   'Rio Limari En Panamericana',
#   'Rio Choapa Sobre El Rio Valle',
#   'Rio Choapa En Cuncumen',
#   'Rio Cuncumen Antes Junta Choapa (Chacay)',
#   'Rio Cuncumen Antes Bocatoma De Canales',
#   'Rio Choapa En Salamanca',
#   'Rio Chalinga En La Palmilla',
#   'Estero Camisas En Desembocadura',
#   'Rio Choapa En Lamahuida',
#   'Rio Choapa En Puente Negro',
#   'Rio Illapel En Las Burras',
#   'Rio Illapel En Huintil',
#   'Rio Illapel En El Peral',
#   'Rio Choapa Aguas Arriba Estero La Canela',
#   'Estero Pupio En El Romero',
#   'Estero Pupio Antes Quebrada Llau-Llau',
#   'Quebrada Llau-Llau',
#   'Rio Sobrante En Piadero',
#   'Rio Pedernal En Tejada',
#   'Rio Chalaco En Embalse',
#   'Rio Petorca En Peon O Hierro Viejo',
#   'Rio Petorca En Longotoma O Puente Ff',
#   'Rio Alicahue En Colliguay',
#   'Rio Ligua En Placilla',
#   'Rio Ligua En Quinquimo',
#   'Estero Quintero En Valle Alegre',
#   'Rio Juncal Ante Junta Rio Blanco',
#   'Rio Juncal En Juncal',
#   'Rio Blanco En Rio Blanco',
#   'Rio Blanco Antes Junta Rio De Los Leones',
#   'Rio Aconcagua En Rio Blanco',
#   'Rio Aconcagua En Los Quilos',
#   'Rio Los Riecillos Antes Junta Rio Colorado',
#   'Rio Colorado En Colorado',
#   'Rio Colorado Antes Junta Rio Aconcagua',
#   'Rio Aconcagua En Vizcachas',
#   'Rio Aconcagua En Chacabuquito',
#   'Rio Aconcagua En San Felipe',
#   'Estero Pocuro En El Sifon',
#   'Estero Pocuro Antes Junta Rio Aconcagua',
#   'Rio Putaendo En Resguardo Los Patos',
#   'Estero Hualtatas En Desembocadura',
#   'Estero De Los Campos En Antes Junta Rio Aconcagua',
#   'Estero Catemu Antes Junta Rio Aconcagua',
#   'Estero Catemu En Puente Santa Rosa',
#   'Estero Las Vegas En Desembocadura',
#   'Estero Las Vegas Aguas Abajo Canal Las Vegas',
#   'Rio Aconcagua En Romeral',
#   'Estero Romeral Antes Junta Rio Aconcagua',
#   'Rio Aconcagua En Panamericana',
#   'Estero Rabuco En Fundo Rabuco',
#   'Estero De Limache Antes Junta Rio Aconcagua',
#   'Rio Maipo En Las Hualtatas',
#   'Rio Maipo En Las Melosas',
#   'Rio Volcan En Queltehues',
#   'Estero Glaciar Echaurren',
#   'Rio Maipo En San Alfonso',
#   'Rio Colorado Antes Junta Rio Olivares',
#   'Rio Olivares Antes Junta Rio Colorado',
#   'Rio Colorado Antes Junta Rio Maipo',
#   'Rio Maipo En El Manzano',
#   'Rio Paine En Longitudinal',
#   'Rio Angostura En Valdivia De Paine',
#   'Rio Molina Antes Junta San Francisco',
#   'Estero Yerba Loca Antes Junta San Francisco',
#   'Rio San Francisco Antes Junta Estero Yerba Loca',
#   'Estero Arrayan En La Montosa',
#   'Rio Mapocho En Los Almendros',
#   'Zanjon De La Aguada Puente Particular',
#   'Quebrada Ramon En Recinto Emos',
#   'Estero Polpaico En Chicauma',
#   'Rio Mapocho Rinconada De Maipu',
#   'Estero Puangue En Boqueron',
#   'Estero Puangue En Ruta 78',
#   'Rio Maipo En Cabimbao',
#   'Rio Las Leas Ante Junta Rio Cachapoal',
#   'Rio Cortaderal Ante Junta Rio Cachapoal',
#   'Rio Cachapoal 5 Km. Aguas Abajo Junta Cortaderal',
#   'Rio Pangal En Pangal',
#   'Rio Cachapoal En Pte Termas De Cauquenes',
#   'Estero De La Cadena Antes Junta Rio Cachapoal',
#   'Rio Claro En Hacienda Las Nieves',
#   'Rio Claro En Tunca',
#   'Estero Zamorano En Puente El Niche',
#   'Rio Cachapoal En Puente Arqueado (Ca)',
#   'Rio Tinguiririca Aguas Abajo Junta Rio Azufre',
#   'Rio Claro En El Valle',
#   'Rio Tinguiririca Bajo Los Briones',
#   'Estero Chimbarongo En Convento Viejo',
#   'Estero Chimbarongo En Ruta 5',
#   'Estero Chimbarongo En Santa Cruz',
#   'Estero Chimbarongo Bajo Embalse Convento Viejo',
#   'Estero Chimbarongo En Puente El Huape',
#   'Rio Tinguiririca En Los Olmos (Ca)',
#   'Estero Alhue En Quilamuta',
#   'Estero Nilahue En Santa Teresa',
#   'Rio Teno En Los QueÑEs',
#   'Rio Teno Bajo Quebrada Infiernillo',
#   'Rio Claro En Los QueÑEs',
#   'Estero El Manzano Antes Junta Rio Teno',
#   'Rio Teno Despues De Junta Con Claro',
#   'Rio Colorado En Junta Con Palos',
#   'Rio Palos En Junta Con Colorado',
#   'Estero Upeo En Upeo',
#   'Rio Mataquito En Licanten',
#   'Rio Huenchullami En Coipue',
#   'Rio Maule En Desague Laguna Del Maule',
#   'Rio Maule En Los BaÑOs',
#   'Rio Cipreses En Dasague Laguna La Invernada',
#   'Estero Las Garzas',
#   'Rio Maule Bajo Boca Toma Maule Central Pehuenche',
#   'Rio Melado En Zona De Presa',
#   'Rio Melado En El Salto',
#   'Rio Claro En San Carlos',
#   'Rio Maule En Armerillo',
#   'Rio Maule En Longitudinal',
#   'Rio Perquilauquen En San Manuel',
#   'Rio Cato En Digua',
#   'Rio Perquilauquen En Gniquen',
#   'Rio Perquilauquen En Quella',
#   'Estero Curipeumo En Lo Hernandez',
#   'Rio Cauquenes En El Arrayan',
#   'Rio Cauquenes En Desembocadura',
#   'Estero Cardo Verde En Lo Ubaldo',
#   'Rio Purapel En Nirivilo',
#   'Rio Purapel En Sauzal',
#   'Rio Longavi En La Quiriquina',
#   'Rio Bullileo En Santa Filomena',
#   'Rio Longavi En El Castillo',
#   'Rio Longavi En Longitudinal',
#   'Rio Achibueno En Los Pegnascos',
#   'Rio Achibueno En La Recova',
#   'Rio Ancoa En El Llepo',
#   'Rio Ancoa En El Morro',
#   'Rio Ancoa Antes Tunel Canal Melado',
#   'Rio Loncomilla En Bodega',
#   'Rio Putagan En Yerbas Buenas',
#   'Rio Loncomilla En Las Brisas',
#   'Rio Claro En Camarico',
#   'Rio Lircay En Puente Las Rastras',
#   'Rio Claro En Talca',
#   'Rio Claro En Rauquen',
#   'Estero Los Puercos En Puente Los Puercos',
#   'Rio Maule En Forel',
#   'Rio Loanco En Desembocadura',
#   'Rio Sauces Antes Junta Con ÑUble',
#   'Rio ÑUble En La Punilla',
#   'Rio ÑUble En San Fabian',
#   'Rio Uble En San Fabian N 2',
#   'Rio Niblinto Antes Canal Alimentador Emb. Coihueco',
#   'Rio Cato En Puente Cato',
#   'Rio Gnuble En Longitudinal',
#   'Rio Chillan En Longitudinal',
#   'Rio Chillan En Esperanza',
#   'Rio Chillan En Camino A Confluencia',
#   'Rio Chillan En Esperanza N 2',
#   'Rio Quilmo En Camino A Yungay (Ca)',
#   'Rio Changaral Camino A Portezuelo',
#   'Rio Itata En Cholguan',
#   'Rio Itata En General Cruz',
#   'Rio Itata En Trilaleo',
#   'Rio Renegado En Invernada',
#   'Rio Diguillin En San Lorenzo (Atacalco)',
#   'Rio Diguillin En Longitudinal',
#   'Rio Itata En Cerro Negro',
#   'Rio Larqui En Camino Yungay',
#   'Rio Larqui En Santa Cruz De Cuca',
#   'Rio Itata En Balsa Nueva Aldea',
#   'Rio Itata En Paso Hondo',
#   'Rio Itata En Coelemu',
#   'Rio Lonquen En Trehuaco',
#   'Estero Bellavista En Tom',
#   'Rio Andalien Camino A Penco',
#   'Estero Nonguen Frente U. Del Bio Bio',
#   'Rio Andalien En Puente Trinitarias',
#   'Rio Andalien Antes Ex Peaje Chaimavida',
#   'Rio Lonquimay Antes Junta Rio Bio Bio',
#   'Rio Bio-Bio En Llanquen',
#   'Rio Lomin En Puente La Junta',
#   'Rio Bio Bio En Angostura Ralco 1',
#   'Rio Bio Bio Ante Junta Huiri Huiri',
#   'Rio Pangue En Captacion',
#   'Rio Bio Bio Ante Junta Pangue',
#   'Rio Huequecura Aguas Arriba De Embalse Angostura',
#   'Rio Biobio En Rucalhue',
#   'Rio Lirquen En Cerro El Padre',
#   'Rio Biobio En La Culebra',
#   'Rio Biobio En Puente Piulo',
#   'Rio Biobio En Longitudinal',
#   'Rio Duqueco En Cerrillos',
#   'Rio Duqueco En Villucura',
#   'Estero Paillihue En Ex Longitudinal Sur',
#   'Rio Mulchen En Mulchen',
#   'Rio Bureo En Mulchen',
#   'Rio Biobio En Coihue',
#   'Rio Renaico En Longitudinal',
#   'Rio Mininco En Longitudinal',
#   'Rio Malleco En La Laguna',
#   'Rio Malleco En Collipulli',
#   'Rio Rahue En Quebrada Culen',
#   'Rio Vergara En Tijeral',
#   'Rio Nicodahue En Pichun',
#   'Estero Quilque En Los Angeles',
#   'Rio Polcura En Cuatro Junta',
#   'Rio Rucue En Camino A Antuco',
#   'Rio Laja En Tucapel',
#   'Rio Laja En Tucapel 2',
#   'Rio Laja Ag.Arr. Del Salto (Rec.R.Laja)',
#   'Rio Laja En Puente Perales',
#   'Rio Claro En Camino Yumbel-Estacion',
#   'Rio Laja En San Rosendo',
#   'Estero Hualqui En Desembocadura',
#   'Rio Biobio En Desembocadura',
#   'Rio Laraquete En El Cajon',
#   'Rio Carampangue En Carampangue',
#   'Rio Curanilahue En Curanilahue',
#   'Estero Plegarias Antes De Jta Rio Curanilahue',
#   'Rio Lebu En Las Corrientes (En Los Alamos)',
#   'Rio Caramavida En Caramavida',
#   'Rio Cayucupil En Cayucupil',
#   'Rio Butamalal En Butamalal',
#   'Rio Reputo En Reputo',
#   'Rio Leiva En Puente Camino A Contulmo',
#   'Rio Tucapel En Cagnete',
#   'Rio Elicura En Puente Elicura',
#   'Rio Lleu-Lleu En Desague Lago Lleu-Lleu',
#   'Rio Puren En Tranaman',
#   'Rio Puren En Puren',
#   'Rio Lumaco En Lumaco',
#   'Rio Traiguen En Victoria',
#   'Rio Dumo En Santa Ana',
#   'Rio Quino En Longitudinal',
#   'Estero Chufquen En Chufquen',
#   'Estero Chanco Camino Curacautin',
#   'Rio Quillen En Longitudinal',
#   'Rio Quillen En Galvarino',
#   'Rio Cholchol En Cholchol',
#   'Rio Blanco En Curacautin',
#   'Rio Cautin En Rari-Ruca',
#   'Rio Collin En Codahue',
#   'Rio Muco En Puente Muco',
#   'Rio Cautin En Cajon',
#   'Rio Quepe En Vilcun',
#   'Rio Huichahue En Faja 24000',
#   'Rio Quepe En Quepe',
#   'Rio Cautin En Almagro',
#   'Rio Truful En Camino Internacional',
#   'Rio Allipen En Melipeuco',
#   'Rio Allipen En Los Laureles',
#   'Rio Curaco En Colico',
#   'Rio Trancura En Curarrehue',
#   'Rio Trancura Antes Rio Llafenco',
#   'Rio Liucura En Liucura',
#   'Rio Tolten En Villarica',
#   'Rio Tolten En Coipue',
#   'Rio Puyehue En Quitratue',
#   'Rio Donguil En Gorbea',
#   'Rio Mahuidanche En Santa Ana',
#   'Rio Tolten En Teodoro Schmidt',
#   'Rio Fui En Desage Lago Pirihueico',
#   'Rio Huahum En La Frontera',
#   'Rio Liquine En Liquine',
#   'Rio San Pedro En Desague Lago Rinihue',
#   'Rio Collileufu En Los Lagos',
#   'Rio Calle Calle En Balsa San Javier',
#   'Rio Calle Calle En Antilhue',
#   'Rio Calle Calle En Pupunahue',
#   'Rio Leufucade En Purulon',
#   'Rio Cruces En Rucaco',
#   'Rio Inaque En Mafil',
#   'Rio Santo Domingo En Rinconada De Piedra',
#   'Rio Futa En Tres Chiflones',
#   'Rio Calcurrupe En Desembocadura',
#   'Rio Caunahue Camino A Llifen',
#   'Rio Nilahue En Mayay',
#   'Rio Bueno En Bueno',
#   'Rio Llollelhue En La Union',
#   'Rio Gol Gol En Puente Nº 2',
#   'Rio Chirre Antes Junta Rio Pilmaiquen',
#   'Rio Pilmaiquen En San Pablo',
#   'Rio Rahue En Desague Lago Rupanco',
#   'Rio Coihueco Antes Junta Pichicope',
#   'Rio Coihueco Antes Junta Rio Rahue',
#   'Rio Rahue Antes Junta Rio Negro',
#   'Rio Rahue En Chan Chan',
#   'Rio Toro En Tegualda',
#   'Rio Negro En Chahuilco',
#   'Rio Damas En Tacamo',
#   'Rio Forrahue En Aromos',
#   'Rio Rahue En Forrahue',
#   'Rio Tranallaguin En Carrico',
#   'Rio Hueyusca En Napeco',
#   'Rio Hueyusca En Camarones',
#   'Rio La Plata Antes Junta Rio Hueyusca',
#   'Rio Negro En Las Lomas',
#   'Rio Maullin En Llanquihue',
#   'Rio Maullin En Las Quemas',
#   'Rio Blanco Ante Junta Rio Chamiza',
#   'Rio Lenca Bajo Bocatoma',
#   'Rio Chamiza Ante Junta Rio Chico',
#   'Rio Chico Ante Rio Chamiza',
#   'Captacion Lenca',
#   'Rio Manso Antes Junta Rio Puelo',
#   'Rio Puelo Antes Junta Con Manso',
#   'Rio Puelo En Desague Lago Tagua Tagua',
#   'Rio Puelo En Carrera Basilio',
#   'Rio Blanco En Chaiten',
#   'Rio Espolon En Desague Lago Espolon',
#   'Rio Futaleufu En La Frontera',
#   'Rio Futaleufu Ante Junta Rio Malito',
#   'Rio Tigre En La Frontera',
#   'Rio Palena Bajo Junta Rosselot',
#   'Rio Ventisquero En Carretera Austral',
#   'Rio Cisnes En Estancia Rio Cisnes',
#   'Rio Cisnes Antes Junta Rio Moro',
#   'Rio Moro Antes Junta Rio Cisnes',
#   'Rio Cisnes En Puerto Cisnes',
#   'Rio Grande En Carretera Austral',
#   'Rio Cuervo En Desembocadura',
#   'Rio ÑIreguao En Villa MaÑIguales',
#   'Rio Emperador Guillermo Antes Junta MaÑIguales',
#   'Rio Magniguales Antes Junta Rio Simpson',
#   'Rio Huemules Frente Cerro Galera',
#   'Rio Oscuro En Camino Cerro Portezuelo',
#   'Rio Blanco Chico Antes Junta Oscuro',
#   'Rio Blanco Antes Junta Huemules',
#   'Rio Pollux Antes Junta Simpson',
#   'Rio Claro En Pisicultura',
#   'Rio Coyhaique En Tejas Verdes',
#   'Rio Simpson Bajo Junta Coyhaique',
#   'Rio Blanco En Desague Lago Caro',
#   'Rio Blanco Antes Junta Rio Aysen',
#   'Rio Aysen En Puerto Aysen',
#   'Rio Lagunillas En Desague Lago Condor',
#   'Rio Ibanez Antes Junta Cajon',
#   'Rio Claro Antes Junta Rio Ibagnez',
#   'Rio Ibaez En Desembocadura',
#   'Rio Murta En Desembocadura',
#   'Rio Jeinimeni En Chile Chico',
#   'Rio El Bagno En Chile Chico',
#   'Rio Baker En Desague Lago Bertrand',
#   'Rio Nef Antes Junta Estero El Revalse',
#   'Rio Cochrane En Cochrane',
#   'Rio Baker En Angostura Chacabuco',
#   'Rio Baker En Colonia',
#   'Rio Baker Bajo ÑAdis',
#   'Rio Mayer En Desembocadura',
#   "Rio Pascua En Desague Lago O'Higgins",
#   'Rio Pascua Ante Junta Rio Quetru',
#   'Rio Paine En Parque Nacional 2',
#   'Rio Baguales En Cerro Guido',
#   'Rio Vizcachas En Cerro Guido',
#   'Rio Don Guillermo En Cerro Castillo',
#   'Rio Las Chinas En Cerro Guido',
#   'Rio Las Chinas Antes Desague Del Toro',
#   'Rio Chorrillos Tres Pasos Ruta N 9',
#   'Rio Tres Pasos En Desague Lago Toro',
#   'Rio Rincon En Ruta Y-290',
#   'Rio Grey Antes Junta Serrano',
#   'Rio Geikie En Desembocadura',
#   'Rio Tindall En Desembocadura',
#   'Rio Caadon 1 En Desembocadura',
#   'Rio Serrano En Desembocadura',
#   'Rio Serrano En Desague Lago Del Toro',
#   'Rio Serrano Antes Junta Grey',
#   'Rio Prat En Desembocadura',
#   'Rio Tranquilo En Ruta N 9',
#   'Rio Hollemberg En Desembocadura',
#   'Rio Grande En Isla Riesco',
#   'Rio Perez En Desembocadura',
#   'Rio Grande En Seno Otway',
#   'Rio Calete En Seno Otway',
#   'Rio San Juan En Desembocadura',
#   'Rio Tres Brazos Antes Bt. Sendos',
#   'Rio Legnadura Antes Bt Sendos',
#   'Rio Las Minas En Bt. Sendos',
#   'Rio Rubens En Ruta N 9',
#   'Rio Penitente En Morro Chico',
#   'Rio Ci-Aike Antes Frontera',
#   'Rio Side En Cerro Sombrero',
#   'Rio Oscar En Bahia San Felipe',
#   'Rio Oro En Bahia San Felipe',
#   'Rio Caleta En Tierra Del Fuego',
#   'Rio Azopardo En Desembocadura',
#   'Rio Cullen En Frontera',
#   'Rio San Martin En San Sebastian',
#   'Rio Chico En Ruta Y-895',
#   'Rio Herminita En Ruta Y-895',
#   'Rio Grande En Tierra Del Fuego',
#   'Rio Catalina En Pampa Guanacos',
#   'Rio Rasmussen En Frontera (Estancia VicuÑA)',
#   'Rio Robalo En Puerto Williams'],
#  'BasicInputTimeSeries': {'fields': ['Year_Mnth_Day',
#    'basin_id',
#    'prcp(mm/day)',
#    'tmean(C)',
#    'QObs(mm/d)'],
#   'index_fields': ['basin_id', 'date'],
#   'initial_date': '1989-10-02T00:00:00.000000',
#   'end_date': '2008-12-31T00:00:00.000000',
#   'time_delta': '1',
#   'time_steps': 7031},
#  'BasicInputStaticProps': {'fields': ['gauge_id',
#    'p_mean_cr2met',
#    'pet_mean',
#    'p_seasonality_cr2met',
#    'frac_snow_cr2met',
#    'aridity_cr2met',
#    'high_prec_freq_cr2met',
#    'high_prec_dur_cr2met',
#    'high_prec_timing_cr2met',
#    'low_prec_freq_cr2met',
#    'low_prec_dur_cr2met',
#    'low_prec_timing_cr2met',
#    'q_mean',
#    'runoff_ratio_cr2met',
#    'slope_fdc',
#    'baseflow_index',
#    'stream_elas_cr2met',
#    'Q5',
#    'Q95',
#    'high_q_freq',
#    'high_q_dur',
#    'low_q_freq',
#    'low_q_dur',
#    'zero_q_freq',
#    'hfd_mean',
#    'gauge_lat',
#    'gauge_lon',
#    'elev_mean',
#    'area',
#    'dom_land_cover'],
#   'index_fileds': ['gauge_id']},
#  'NpropperTimeStatic': 29}
